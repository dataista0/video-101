# %% [markdown]
# # Facedetection with Mediapipe
#
# Following this tutorial: https://www.youtube.com/watch?v=K4nn4YdSMFM

# %%
# %matplotlib auto

import cv2
import mediapipe as mp
import time

WEBCAM_ID = 2
VIDEO_PATH = "../data/short.webm"



def face_detection(video_source=WEBCAM_ID):
    mp_facedetector = mp.solutions.face_detection
    mp_draw = mp.solutions.drawing_utils
    
    cap = cv2.VideoCapture(video_source)

    with mp_facedetector.FaceDetection(min_detection_confidence=0.7) as face_detection:
        while cap.isOpened():
            success, image = cap.read()
            start = time.time()
            
            if not success and (cv2.waitKey(1000) & 0xFF == 27):
                break
                
            # Convert BGR image to RGB
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            results = face_detection.process(image)

            # Convert the image color back so it can be displayed
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            if results.detections:
                for id, detection in enumerate(results.detections):
                    print(id, detection)
                    mp_draw.draw_detection(image, detection)
                    bbox = detection.location_data.relative_bounding_box
                    h, w, c = image.shape

                    bbox_text = int(bbox.xmin * w), int(bbox.ymin * h), int(bbox.width * w), int(bbox.height * h)
                    cv2.putText(image, f'{int(detection.score[0]*100)}%', (bbox_text[0], bbox_text[1]-20), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)

            end = time.time()
            total_time = end - start
            fps = 1 / total_time

            cv2.putText(image, f'FPS: {int(fps)}', (20,70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
            cv2.imshow('Face Detection', image)
            
            if cv2.waitKey(5) & 0xFF == 27:
                break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Using matplotlib backend: <object object at 0x7f24e41faa10>

# %%
face_detection(VIDEO_PATH)
# Out:
# 0 label_id: 0
# score: 0.924086332321167
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3716214597225189
#     ymin: 0.37353867292404175
#     width: 0.26425251364707947
#     height: 0.46978139877319336
#   }
#   relative_keypoints {
#     x: 0.4516926407814026
#     y: 0.5032829642295837
#   }
#   relative_keypoints {
#     x: 0.5574453473091125
#     y: 0.49510931968688965
#   }
#   relative_keypoints {
#     x: 0.5058767795562744
#     y: 0.6050108671188354
#   }
#   relative_keypoints {
#     x: 0.5069026350975037
#     y: 0.703906238079071
#   }
#   relative_keypoints {
#     x: 0.39106330275535583
#     y: 0.5620597004890442
#   }
#   relative_keypoints {
#     x: 0.6157304644584656
#     y: 0.5503236055374146
#   }
# }
#
# 0 label_id: 0
# score: 0.9234042763710022
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3746071755886078
#     ymin: 0.3784218430519104
#     width: 0.25925371050834656
#     height: 0.4608948230743408
#   }
#   relative_keypoints {
#     x: 0.45078614354133606
#     y: 0.5032790303230286
#   }
#   relative_keypoints {
#     x: 0.556341826915741
#     y: 0.49159473180770874
#   }
#   relative_keypoints {
#     x: 0.5047412514686584
#     y: 0.5963642597198486
#   }
#   relative_keypoints {
#     x: 0.5067078471183777
#     y: 0.6967220902442932
#   }
#   relative_keypoints {
#     x: 0.391360342502594
#     y: 0.5690237879753113
#   }
#   relative_keypoints {
#     x: 0.6159448623657227
#     y: 0.5514585971832275
#   }
# }
#
# 0 label_id: 0
# score: 0.9172705411911011
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3750171363353729
#     ymin: 0.38367509841918945
#     width: 0.25381848216056824
#     height: 0.45123201608657837
#   }
#   relative_keypoints {
#     x: 0.44504114985466003
#     y: 0.5049862265586853
#   }
#   relative_keypoints {
#     x: 0.5483061075210571
#     y: 0.4927576184272766
#   }
#   relative_keypoints {
#     x: 0.49457311630249023
#     y: 0.5935187935829163
#   }
#   relative_keypoints {
#     x: 0.49805301427841187
#     y: 0.6929420828819275
#   }
#   relative_keypoints {
#     x: 0.3919820189476013
#     y: 0.5708795189857483
#   }
#   relative_keypoints {
#     x: 0.6125909686088562
#     y: 0.553618848323822
#   }
# }
#
# 0 label_id: 0
# score: 0.8919241428375244
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.378544420003891
#     ymin: 0.3946611285209656
#     width: 0.24466672539710999
#     height: 0.43496274948120117
#   }
#   relative_keypoints {
#     x: 0.44636115431785583
#     y: 0.506769061088562
#   }
#   relative_keypoints {
#     x: 0.5486987829208374
#     y: 0.5009487867355347
#   }
#   relative_keypoints {
#     x: 0.49481943249702454
#     y: 0.5937516689300537
#   }
#   relative_keypoints {
#     x: 0.4966411590576172
#     y: 0.6914876103401184
#   }
#   relative_keypoints {
#     x: 0.3920907974243164
#     y: 0.5689258575439453
#   }
#   relative_keypoints {
#     x: 0.6098883152008057
#     y: 0.5636683702468872
#   }
# }
#
# 0 label_id: 0
# score: 0.8913589119911194
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3770744800567627
#     ymin: 0.391310453414917
#     width: 0.24579012393951416
#     height: 0.4369592070579529
#   }
#   relative_keypoints {
#     x: 0.44629335403442383
#     y: 0.5033998489379883
#   }
#   relative_keypoints {
#     x: 0.5479771494865417
#     y: 0.49875563383102417
#   }
#   relative_keypoints {
#     x: 0.49406081438064575
#     y: 0.5896822810173035
#   }
#   relative_keypoints {
#     x: 0.49522876739501953
#     y: 0.6880819201469421
#   }
#   relative_keypoints {
#     x: 0.3914986848831177
#     y: 0.5664637684822083
#   }
#   relative_keypoints {
#     x: 0.6089379191398621
#     y: 0.5642340183258057
#   }
# }
#
# 0 label_id: 0
# score: 0.8971392512321472
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3763033449649811
#     ymin: 0.3879721164703369
#     width: 0.24807384610176086
#     height: 0.4410192370414734
#   }
#   relative_keypoints {
#     x: 0.44664567708969116
#     y: 0.5052976608276367
#   }
#   relative_keypoints {
#     x: 0.5483537912368774
#     y: 0.4998496174812317
#   }
#   relative_keypoints {
#     x: 0.49541544914245605
#     y: 0.5958672761917114
#   }
#   relative_keypoints {
#     x: 0.4969142973423004
#     y: 0.6922411322593689
#   }
#   relative_keypoints {
#     x: 0.3916966915130615
#     y: 0.5634972453117371
#   }
#   relative_keypoints {
#     x: 0.6093227863311768
#     y: 0.5586827397346497
#   }
# }
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 0 label_id: 0
# score: 0.9092839360237122
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36697766184806824
#     ymin: 0.38505685329437256
#     width: 0.2531217634677887
#     height: 0.44999319314956665
#   }
#   relative_keypoints {
#     x: 0.4392551779747009
#     y: 0.5023022890090942
#   }
#   relative_keypoints {
#     x: 0.5443441271781921
#     y: 0.49599653482437134
#   }
#   relative_keypoints {
#     x: 0.4913574457168579
#     y: 0.5930129289627075
#   }
#   relative_keypoints {
#     x: 0.492591917514801
#     y: 0.6934862732887268
#   }
#   relative_keypoints {
#     x: 0.3809208571910858
#     y: 0.5662636160850525
#   }
#   relative_keypoints {
#     x: 0.6049215793609619
#     y: 0.5592974424362183
#   }
# }
#
# 0 label_id: 0
# score: 0.9263020753860474
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3595026433467865
#     ymin: 0.3761802315711975
#     width: 0.2605457603931427
#     height: 0.46319150924682617
#   }
#   relative_keypoints {
#     x: 0.43270039558410645
#     y: 0.5042269825935364
#   }
#   relative_keypoints {
#     x: 0.538069486618042
#     y: 0.4962078332901001
#   }
#   relative_keypoints {
#     x: 0.48347705602645874
#     y: 0.6052587032318115
#   }
#   relative_keypoints {
#     x: 0.48578941822052
#     y: 0.702233612537384
#   }
#   relative_keypoints {
#     x: 0.3783234655857086
#     y: 0.558120846748352
#   }
#   relative_keypoints {
#     x: 0.602609395980835
#     y: 0.5480166673660278
#   }
# }
#
# 0 label_id: 0
# score: 0.9131660461425781
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.354841411113739
#     ymin: 0.3821723461151123
#     width: 0.258200466632843
#     height: 0.45902198553085327
#   }
#   relative_keypoints {
#     x: 0.42700180411338806
#     y: 0.5052785873413086
#   }
#   relative_keypoints {
#     x: 0.5331392884254456
#     y: 0.4971388578414917
#   }
#   relative_keypoints {
#     x: 0.47940149903297424
#     y: 0.6016547083854675
#   }
#   relative_keypoints {
#     x: 0.4813266098499298
#     y: 0.7019988894462585
#   }
#   relative_keypoints {
#     x: 0.37118470668792725
#     y: 0.5646817088127136
#   }
#   relative_keypoints {
#     x: 0.5963206887245178
#     y: 0.5540363788604736
#   }
# }
#
# 0 label_id: 0
# score: 0.9207063317298889
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3517391085624695
#     ymin: 0.3804164528846741
#     width: 0.2601659893989563
#     height: 0.46251606941223145
#   }
#   relative_keypoints {
#     x: 0.42742660641670227
#     y: 0.50694340467453
#   }
#   relative_keypoints {
#     x: 0.5334739089012146
#     y: 0.49675387144088745
#   }
#   relative_keypoints {
#     x: 0.4820857644081116
#     y: 0.6045690178871155
#   }
#   relative_keypoints {
#     x: 0.48367974162101746
#     y: 0.7041053175926208
#   }
#   relative_keypoints {
#     x: 0.36873331665992737
#     y: 0.5654568076133728
#   }
#   relative_keypoints {
#     x: 0.5938683152198792
#     y: 0.5504391193389893
#   }
# }
#
# 0 label_id: 0
# score: 0.9148562550544739
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3526988923549652
#     ymin: 0.3804817199707031
#     width: 0.257034569978714
#     height: 0.45694929361343384
#   }
#   relative_keypoints {
#     x: 0.42738819122314453
#     y: 0.5035322904586792
#   }
#   relative_keypoints {
#     x: 0.5331721901893616
#     y: 0.4957813620567322
#   }
#   relative_keypoints {
#     x: 0.48153769969940186
#     y: 0.5998222827911377
#   }
#   relative_keypoints {
#     x: 0.48242586851119995
#     y: 0.6992881894111633
#   }
#   relative_keypoints {
#     x: 0.36843132972717285
#     y: 0.5617602467536926
#   }
#   relative_keypoints {
#     x: 0.5929114818572998
#     y: 0.5513859987258911
#   }
# }
#
# 0 label_id: 0
# score: 0.9159045815467834
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35239848494529724
#     ymin: 0.37763339281082153
#     width: 0.2578892409801483
#     height: 0.4584686756134033
#   }
#   relative_keypoints {
#     x: 0.4296819567680359
#     y: 0.5006961822509766
#   }
#   relative_keypoints {
#     x: 0.5350655913352966
#     y: 0.49503999948501587
#   }
#   relative_keypoints {
#     x: 0.48480862379074097
#     y: 0.5992253422737122
#   }
#   relative_keypoints {
#     x: 0.4846206307411194
#     y: 0.6982751488685608
#   }
#   relative_keypoints {
#     x: 0.36842212080955505
#     y: 0.5574507117271423
#   }
#   relative_keypoints {
#     x: 0.5919742584228516
#     y: 0.5505828857421875
#   }
# }
#
# 0 label_id: 0
# score: 0.9173634648323059
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3535831868648529
#     ymin: 0.376706063747406
#     width: 0.25909993052482605
#     height: 0.4606211185455322
#   }
#   relative_keypoints {
#     x: 0.42948561906814575
#     y: 0.5022237300872803
#   }
#   relative_keypoints {
#     x: 0.5343812704086304
#     y: 0.49741601943969727
#   }
#   relative_keypoints {
#     x: 0.4822773039340973
#     y: 0.6043274998664856
#   }
#   relative_keypoints {
#     x: 0.48284703493118286
#     y: 0.7015138268470764
#   }
#   relative_keypoints {
#     x: 0.3714336156845093
#     y: 0.5552090406417847
#   }
#   relative_keypoints {
#     x: 0.5939170718193054
#     y: 0.5499811172485352
#   }
# }
#
# 0 label_id: 0
# score: 0.9218766093254089
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35267946124076843
#     ymin: 0.3750002384185791
#     width: 0.25812748074531555
#     height: 0.4588924050331116
#   }
#   relative_keypoints {
#     x: 0.4282143712043762
#     y: 0.49726951122283936
#   }
#   relative_keypoints {
#     x: 0.533214807510376
#     y: 0.49220430850982666
#   }
#   relative_keypoints {
#     x: 0.48103103041648865
#     y: 0.5965287089347839
#   }
#   relative_keypoints {
#     x: 0.48140275478363037
#     y: 0.6956164240837097
#   }
#   relative_keypoints {
#     x: 0.3698403537273407
#     y: 0.5542733669281006
#   }
#   relative_keypoints {
#     x: 0.5923439860343933
#     y: 0.5496029257774353
#   }
# }
#
# 0 label_id: 0
# score: 0.9128319621086121
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3523310422897339
#     ymin: 0.37726491689682007
#     width: 0.2607947587966919
#     height: 0.4636344909667969
#   }
#   relative_keypoints {
#     x: 0.4302537441253662
#     y: 0.502598762512207
#   }
#   relative_keypoints {
#     x: 0.5362311005592346
#     y: 0.49880897998809814
#   }
#   relative_keypoints {
#     x: 0.4843253195285797
#     y: 0.6054039001464844
#   }
#   relative_keypoints {
#     x: 0.4841993749141693
#     y: 0.7039254307746887
#   }
#   relative_keypoints {
#     x: 0.36975446343421936
#     y: 0.5567529201507568
#   }
#   relative_keypoints {
#     x: 0.5941668152809143
#     y: 0.5531153082847595
#   }
# }
#
# 0 label_id: 0
# score: 0.9126835465431213
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3540812134742737
#     ymin: 0.37536555528640747
#     width: 0.2584662437438965
#     height: 0.45949459075927734
#   }
#   relative_keypoints {
#     x: 0.4343224763870239
#     y: 0.4984254240989685
#   }
#   relative_keypoints {
#     x: 0.5390369296073914
#     y: 0.4991528391838074
#   }
#   relative_keypoints {
#     x: 0.48878830671310425
#     y: 0.6035258769989014
#   }
#   relative_keypoints {
#     x: 0.48659342527389526
#     y: 0.7002049088478088
#   }
#   relative_keypoints {
#     x: 0.37057650089263916
#     y: 0.5479552149772644
#   }
#   relative_keypoints {
#     x: 0.5925758481025696
#     y: 0.5531601309776306
#   }
# }
#
# 0 label_id: 0
# score: 0.913237988948822
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35446423292160034
#     ymin: 0.37578147649765015
#     width: 0.26072102785110474
#     height: 0.46350300312042236
#   }
#   relative_keypoints {
#     x: 0.4337177276611328
#     y: 0.501275897026062
#   }
#   relative_keypoints {
#     x: 0.5391843914985657
#     y: 0.5001680850982666
#   }
#   relative_keypoints {
#     x: 0.4878530204296112
#     y: 0.6068630218505859
#   }
#   relative_keypoints {
#     x: 0.4866941273212433
#     y: 0.7037965655326843
#   }
#   relative_keypoints {
#     x: 0.3713170886039734
#     y: 0.5515059232711792
#   }
#   relative_keypoints {
#     x: 0.5952820777893066
#     y: 0.5529342293739319
#   }
# }
#
# 0 label_id: 0
# score: 0.9136989712715149
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3556447923183441
#     ymin: 0.3763892650604248
#     width: 0.25838765501976013
#     height: 0.4593546986579895
#   }
#   relative_keypoints {
#     x: 0.4333275258541107
#     y: 0.4981769323348999
#   }
#   relative_keypoints {
#     x: 0.5386369228363037
#     y: 0.4984663128852844
#   }
#   relative_keypoints {
#     x: 0.4863561689853668
#     y: 0.6016557216644287
#   }
#   relative_keypoints {
#     x: 0.4850184917449951
#     y: 0.6993815302848816
#   }
#   relative_keypoints {
#     x: 0.371728777885437
#     y: 0.5499029159545898
#   }
#   relative_keypoints {
#     x: 0.5951505899429321
#     y: 0.5547807216644287
#   }
# }
#
# 0 label_id: 0
# score: 0.9161195158958435
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3543657958507538
#     ymin: 0.3720315098762512
#     width: 0.2615271508693695
#     height: 0.46493613719940186
#   }
#   relative_keypoints {
#     x: 0.43456247448921204
#     y: 0.4989773631095886
#   }
#   relative_keypoints {
#     x: 0.5397392511367798
#     y: 0.4995988607406616
#   }
#   relative_keypoints {
#     x: 0.4883115887641907
#     y: 0.6078393459320068
#   }
#   relative_keypoints {
#     x: 0.486680269241333
#     y: 0.7032456994056702
#   }
#   relative_keypoints {
#     x: 0.37196609377861023
#     y: 0.5456946492195129
#   }
#   relative_keypoints {
#     x: 0.5952754020690918
#     y: 0.5503929853439331
#   }
# }
#
# 0 label_id: 0
# score: 0.9183301329612732
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.355065256357193
#     ymin: 0.3740236759185791
#     width: 0.26013514399528503
#     height: 0.46246153116226196
#   }
#   relative_keypoints {
#     x: 0.4326425790786743
#     y: 0.4989323616027832
#   }
#   relative_keypoints {
#     x: 0.5382345914840698
#     y: 0.4988974928855896
#   }
#   relative_keypoints {
#     x: 0.4855697751045227
#     y: 0.6052185893058777
#   }
#   relative_keypoints {
#     x: 0.48455721139907837
#     y: 0.7014732956886292
#   }
#   relative_keypoints {
#     x: 0.37177789211273193
#     y: 0.5474519729614258
#   }
#   relative_keypoints {
#     x: 0.5960776805877686
#     y: 0.551600992679596
#   }
# }
#
# 0 label_id: 0
# score: 0.9226157665252686
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3564671576023102
#     ymin: 0.37798869609832764
#     width: 0.26049235463142395
#     height: 0.463096559047699
#   }
#   relative_keypoints {
#     x: 0.4304599165916443
#     y: 0.5038577318191528
#   }
#   relative_keypoints {
#     x: 0.5371625423431396
#     y: 0.49838221073150635
#   }
#   relative_keypoints {
#     x: 0.4828703999519348
#     y: 0.6054972410202026
#   }
#   relative_keypoints {
#     x: 0.4839981198310852
#     y: 0.7033355832099915
#   }
#   relative_keypoints {
#     x: 0.3729586899280548
#     y: 0.5574983954429626
#   }
#   relative_keypoints {
#     x: 0.5997829437255859
#     y: 0.5517784953117371
#   }
# }
#
# 0 label_id: 0
# score: 0.9228499531745911
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35458236932754517
#     ymin: 0.37688636779785156
#     width: 0.26229768991470337
#     height: 0.46630579233169556
#   }
#   relative_keypoints {
#     x: 0.43128547072410583
#     y: 0.5045352578163147
#   }
#   relative_keypoints {
#     x: 0.5382617115974426
#     y: 0.4976940155029297
#   }
#   relative_keypoints {
#     x: 0.48604169487953186
#     y: 0.6065981984138489
#   }
#   relative_keypoints {
#     x: 0.4868701696395874
#     y: 0.7048489451408386
#   }
#   relative_keypoints {
#     x: 0.37137407064437866
#     y: 0.5593705773353577
#   }
#   relative_keypoints {
#     x: 0.5985292196273804
#     y: 0.5501155853271484
#   }
# }
#
# 0 label_id: 0
# score: 0.9225628972053528
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3534427881240845
#     ymin: 0.37608814239501953
#     width: 0.26312166452407837
#     height: 0.46777087450027466
#   }
#   relative_keypoints {
#     x: 0.4315183162689209
#     y: 0.504089891910553
#   }
#   relative_keypoints {
#     x: 0.5386675596237183
#     y: 0.4962308406829834
#   }
#   relative_keypoints {
#     x: 0.48746705055236816
#     y: 0.6053791046142578
#   }
#   relative_keypoints {
#     x: 0.4880582094192505
#     y: 0.7044700980186462
#   }
#   relative_keypoints {
#     x: 0.3700721263885498
#     y: 0.5608309507369995
#   }
#   relative_keypoints {
#     x: 0.5976854562759399
#     y: 0.5498221516609192
#   }
# }
# 0 label_id: 0
# score: 0.9265680909156799
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.356469988822937
#     ymin: 0.3783465623855591
#     width: 0.26041048765182495
#     height: 0.4629508852958679
#   }
#   relative_keypoints {
#     x: 0.4315786361694336
#     y: 0.5056176781654358
#   }
#   relative_keypoints {
#     x: 0.5376670360565186
#     y: 0.4970773458480835
#   }
#   relative_keypoints {
#     x: 0.48551419377326965
#     y: 0.6050419211387634
#   }
#   relative_keypoints {
#     x: 0.4871256649494171
#     y: 0.7028617262840271
#   }
#   relative_keypoints {
#     x: 0.3733142018318176
#     y: 0.5618340969085693
#   }
#   relative_keypoints {
#     x: 0.5989004373550415
#     y: 0.5494839549064636
#   }
# }
#
# 0 label_id: 0
# score: 0.9301075339317322
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35807934403419495
#     ymin: 0.3754349946975708
#     width: 0.2605721652507782
#     height: 0.4632384181022644
#   }
#   relative_keypoints {
#     x: 0.43271228671073914
#     y: 0.5029674172401428
#   }
#   relative_keypoints {
#     x: 0.5387332439422607
#     y: 0.494831919670105
#   }
#   relative_keypoints {
#     x: 0.4858298599720001
#     y: 0.6035852432250977
#   }
#   relative_keypoints {
#     x: 0.4876636266708374
#     y: 0.7011188864707947
#   }
#   relative_keypoints {
#     x: 0.37540075182914734
#     y: 0.5584312081336975
#   }
#   relative_keypoints {
#     x: 0.6008692979812622
#     y: 0.5468065738677979
#   }
# }
#
# 0 label_id: 0
# score: 0.9242125749588013
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.359958291053772
#     ymin: 0.3806321620941162
#     width: 0.25955480337142944
#     height: 0.46142977476119995
#   }
#   relative_keypoints {
#     x: 0.4351204037666321
#     y: 0.5050476789474487
#   }
#   relative_keypoints {
#     x: 0.5410955548286438
#     y: 0.4980130195617676
#   }
#   relative_keypoints {
#     x: 0.4883536994457245
#     y: 0.6030452251434326
#   }
#   relative_keypoints {
#     x: 0.48966479301452637
#     y: 0.7022477984428406
#   }
#   relative_keypoints {
#     x: 0.37605613470077515
#     y: 0.5637122392654419
#   }
#   relative_keypoints {
#     x: 0.6019735336303711
#     y: 0.5543038845062256
#   }
# }
#
# 0 label_id: 0
# score: 0.9174796342849731
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36167004704475403
#     ymin: 0.37975430488586426
#     width: 0.2589890658855438
#     height: 0.46042412519454956
#   }
#   relative_keypoints {
#     x: 0.43481898307800293
#     y: 0.5058615207672119
#   }
#   relative_keypoints {
#     x: 0.5400823354721069
#     y: 0.5001380443572998
#   }
#   relative_keypoints {
#     x: 0.4855506420135498
#     y: 0.6069485545158386
#   }
#   relative_keypoints {
#     x: 0.4875774681568146
#     y: 0.7038494944572449
#   }
#   relative_keypoints {
#     x: 0.3793679177761078
#     y: 0.5599747896194458
#   }
#   relative_keypoints {
#     x: 0.6034343838691711
#     y: 0.5528324842453003
#   }
# }
#
# 0 label_id: 0
# score: 0.9213240146636963
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36306771636009216
#     ymin: 0.3827301859855652
#     width: 0.25537851452827454
#     height: 0.45400524139404297
#   }
#   relative_keypoints {
#     x: 0.43497589230537415
#     y: 0.5051085948944092
#   }
#   relative_keypoints {
#     x: 0.5399792790412903
#     y: 0.5005813241004944
#   }
#   relative_keypoints {
#     x: 0.4857787489891052
#     y: 0.603403627872467
#   }
#   relative_keypoints {
#     x: 0.48738110065460205
#     y: 0.7006158232688904
#   }
#   relative_keypoints {
#     x: 0.3789573907852173
#     y: 0.5603525638580322
#   }
#   relative_keypoints {
#     x: 0.6024844646453857
#     y: 0.5552546977996826
#   }
# }
#
# 0 label_id: 0
# score: 0.9249086380004883
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36277613043785095
#     ymin: 0.38240647315979004
#     width: 0.2559063136577606
#     height: 0.4549434781074524
#   }
#   relative_keypoints {
#     x: 0.43412402272224426
#     y: 0.5048266649246216
#   }
#   relative_keypoints {
#     x: 0.5389595627784729
#     y: 0.49972349405288696
#   }
#   relative_keypoints {
#     x: 0.48400530219078064
#     y: 0.6028664708137512
#   }
#   relative_keypoints {
#     x: 0.48598799109458923
#     y: 0.7004815936088562
#   }
#   relative_keypoints {
#     x: 0.3793538212776184
#     y: 0.5608845949172974
#   }
#   relative_keypoints {
#     x: 0.6028631925582886
#     y: 0.5551440715789795
#   }
# }
#
# 0 label_id: 0
# score: 0.931806206703186
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3590492606163025
#     ymin: 0.3767569661140442
#     width: 0.2596815228462219
#     height: 0.46165478229522705
#   }
#   relative_keypoints {
#     x: 0.4320472478866577
#     y: 0.502604067325592
#   }
#   relative_keypoints {
#     x: 0.5377294421195984
#     y: 0.49676454067230225
#   }
#   relative_keypoints {
#     x: 0.482779860496521
#     y: 0.603935956954956
#   }
#   relative_keypoints {
#     x: 0.48469316959381104
#     y: 0.7011719346046448
#   }
#   relative_keypoints {
#     x: 0.3767862021923065
#     y: 0.5567080974578857
#   }
#   relative_keypoints {
#     x: 0.6019065976142883
#     y: 0.5498278141021729
#   }
# }
#
# 0 label_id: 0
# score: 0.930294394493103
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3581913113594055
#     ymin: 0.3739736080169678
#     width: 0.2589191794395447
#     height: 0.4602997899055481
#   }
#   relative_keypoints {
#     x: 0.43201449513435364
#     y: 0.5012276768684387
#   }
#   relative_keypoints {
#     x: 0.5368965268135071
#     y: 0.4947569966316223
#   }
#   relative_keypoints {
#     x: 0.4834567606449127
#     y: 0.6031777262687683
#   }
#   relative_keypoints {
#     x: 0.48522838950157166
#     y: 0.6989595293998718
#   }
#   relative_keypoints {
#     x: 0.3763132095336914
#     y: 0.5534576773643494
#   }
#   relative_keypoints {
#     x: 0.5994824767112732
#     y: 0.5450537204742432
#   }
# }
#
# 0 label_id: 0
# score: 0.9241618514060974
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3583505153656006
#     ymin: 0.37838131189346313
#     width: 0.255667507648468
#     height: 0.45451903343200684
#   }
#   relative_keypoints {
#     x: 0.43136367201805115
#     y: 0.5026676654815674
#   }
#   relative_keypoints {
#     x: 0.5359257459640503
#     y: 0.49602967500686646
#   }
#   relative_keypoints {
#     x: 0.4835081100463867
#     y: 0.6012347340583801
#   }
#   relative_keypoints {
#     x: 0.48498761653900146
#     y: 0.6975632309913635
#   }
#   relative_keypoints {
#     x: 0.3747694194316864
#     y: 0.5572331547737122
#   }
#   relative_keypoints {
#     x: 0.5966172218322754
#     y: 0.548188328742981
#   }
# }
#
# 0 label_id: 0
# score: 0.9224820733070374
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3572843074798584
#     ymin: 0.379949152469635
#     width: 0.25578540563583374
#     height: 0.4547286033630371
#   }
#   relative_keypoints {
#     x: 0.43050774931907654
#     y: 0.49962395429611206
#   }
#   relative_keypoints {
#     x: 0.5366276502609253
#     y: 0.4971807599067688
#   }
#   relative_keypoints {
#     x: 0.48249250650405884
#     y: 0.5980778932571411
#   }
#   relative_keypoints {
#     x: 0.48248887062072754
#     y: 0.6968709826469421
#   }
#   relative_keypoints {
#     x: 0.37173765897750854
#     y: 0.5555053353309631
#   }
#   relative_keypoints {
#     x: 0.59666508436203
#     y: 0.555718719959259
#   }
# }
#
# 0 label_id: 0
# score: 0.922615647315979
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35588160157203674
#     ymin: 0.38186192512512207
#     width: 0.2576608955860138
#     height: 0.45806294679641724
#   }
#   relative_keypoints {
#     x: 0.430123895406723
#     y: 0.5040716528892517
#   }
#   relative_keypoints {
#     x: 0.536658525466919
#     y: 0.4993135333061218
#   }
#   relative_keypoints {
#     x: 0.4837612509727478
#     y: 0.6024439930915833
#   }
#   relative_keypoints {
#     x: 0.4843681752681732
#     y: 0.7013210654258728
#   }
#   relative_keypoints {
#     x: 0.37041258811950684
#     y: 0.5610156655311584
#   }
#   relative_keypoints {
#     x: 0.5965743660926819
#     y: 0.5557331442832947
#   }
# }
#
# 0 label_id: 0
# score: 0.9248691201210022
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35459673404693604
#     ymin: 0.37592828273773193
#     width: 0.26249057054519653
#     height: 0.4666491150856018
#   }
#   relative_keypoints {
#     x: 0.43327465653419495
#     y: 0.5018803477287292
#   }
#   relative_keypoints {
#     x: 0.5401760935783386
#     y: 0.495586633682251
#   }
#   relative_keypoints {
#     x: 0.4888584315776825
#     y: 0.6028296947479248
#   }
#   relative_keypoints {
#     x: 0.4891165494918823
#     y: 0.7025160193443298
#   }
#   relative_keypoints {
#     x: 0.3712131977081299
#     y: 0.5590311884880066
#   }
#   relative_keypoints {
#     x: 0.5982372164726257
#     y: 0.5510432720184326
#   }
# }
#
# 0 label_id: 0
# score: 0.9278866052627563
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35436737537384033
#     ymin: 0.3774716854095459
#     width: 0.2638400197029114
#     height: 0.4690476059913635
#   }
#   relative_keypoints {
#     x: 0.43212953209877014
#     y: 0.5049615502357483
#   }
#   relative_keypoints {
#     x: 0.5397286415100098
#     y: 0.4963977336883545
#   }
#   relative_keypoints {
#     x: 0.48806682229042053
#     y: 0.604767918586731
#   }
#   relative_keypoints {
#     x: 0.48922571539878845
#     y: 0.7052430510520935
#   }
#   relative_keypoints {
#     x: 0.3710460066795349
#     y: 0.5644136071205139
#   }
#   relative_keypoints {
#     x: 0.5996367931365967
#     y: 0.5515922904014587
#   }
# }
#
# 0 label_id: 0
# score: 0.9267591834068298
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3545377552509308
#     ymin: 0.3752731680870056
#     width: 0.26375266909599304
#     height: 0.4688926935195923
#   }
#   relative_keypoints {
#     x: 0.4323939085006714
#     y: 0.5037340521812439
#   }
#   relative_keypoints {
#     x: 0.5400622487068176
#     y: 0.49718302488327026
#   }
#   relative_keypoints {
#     x: 0.4881265163421631
#     y: 0.6067469120025635
#   }
#   relative_keypoints {
#     x: 0.4889766275882721
#     y: 0.7055720686912537
#   }
#   relative_keypoints {
#     x: 0.3713165819644928
#     y: 0.5590237379074097
#   }
#   relative_keypoints {
#     x: 0.5998530387878418
#     y: 0.5492566227912903
#   }
# }
#
# 0 label_id: 0
# score: 0.9274977445602417
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3579033613204956
#     ymin: 0.3778635859489441
#     width: 0.26075541973114014
#     height: 0.4635641574859619
#   }
#   relative_keypoints {
#     x: 0.4340709447860718
#     y: 0.5048224329948425
#   }
#   relative_keypoints {
#     x: 0.5399618148803711
#     y: 0.4966825842857361
#   }
#   relative_keypoints {
#     x: 0.48807063698768616
#     y: 0.6044972538948059
#   }
#   relative_keypoints {
#     x: 0.48958227038383484
#     y: 0.7027515769004822
#   }
#   relative_keypoints {
#     x: 0.37511155009269714
#     y: 0.5617754459381104
#   }
#   relative_keypoints {
#     x: 0.6005608439445496
#     y: 0.5497760772705078
#   }
# }
#
# 0 label_id: 0
# score: 0.9290702939033508
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3606046736240387
#     ymin: 0.3783031702041626
#     width: 0.25828394293785095
#     height: 0.45917052030563354
#   }
#   relative_keypoints {
#     x: 0.4344486892223358
#     y: 0.5044599175453186
#   }
#   relative_keypoints {
#     x: 0.5398896336555481
#     y: 0.49514132738113403
#   }
#   relative_keypoints {
#     x: 0.48762887716293335
#     y: 0.6019601821899414
#   }
#   relative_keypoints {
#     x: 0.4899265170097351
#     y: 0.699713408946991
#   }
#   relative_keypoints {
#     x: 0.3773275315761566
#     y: 0.5620866417884827
#   }
#   relative_keypoints {
#     x: 0.6018641591072083
#     y: 0.5476815700531006
#   }
# }
#
# 0 label_id: 0
# score: 0.9270833730697632
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3586004078388214
#     ymin: 0.37624722719192505
#     width: 0.2588248550891876
#     height: 0.4601321220397949
#   }
#   relative_keypoints {
#     x: 0.4332682490348816
#     y: 0.502045214176178
#   }
#   relative_keypoints {
#     x: 0.5388085842132568
#     y: 0.49495619535446167
#   }
#   relative_keypoints {
#     x: 0.486108660697937
#     y: 0.6020428538322449
#   }
#   relative_keypoints {
#     x: 0.4877219796180725
#     y: 0.6993839144706726
#   }
#   relative_keypoints {
#     x: 0.37575361132621765
#     y: 0.5571760535240173
#   }
#   relative_keypoints {
#     x: 0.6001617908477783
#     y: 0.5474207997322083
#   }
# }
#
# 0 label_id: 0
# score: 0.9314407110214233
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3588423728942871
#     ymin: 0.3771054744720459
#     width: 0.25794780254364014
#     height: 0.45857304334640503
#   }
#   relative_keypoints {
#     x: 0.4337453544139862
#     y: 0.5013296604156494
#   }
#   relative_keypoints {
#     x: 0.5390143394470215
#     y: 0.49547892808914185
#   }
#   relative_keypoints {
#     x: 0.48634663224220276
#     y: 0.6008989810943604
#   }
#   relative_keypoints {
#     x: 0.4874402582645416
#     y: 0.6983309388160706
#   }
#   relative_keypoints {
#     x: 0.375557005405426
#     y: 0.556223452091217
#   }
#   relative_keypoints {
#     x: 0.5996163487434387
#     y: 0.5490995049476624
#   }
# }
# 0 label_id: 0
# score: 0.9298142790794373
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36007747054100037
#     ymin: 0.3775492310523987
#     width: 0.2573840320110321
#     height: 0.45757055282592773
#   }
#   relative_keypoints {
#     x: 0.43269312381744385
#     y: 0.5029426217079163
#   }
#   relative_keypoints {
#     x: 0.5384864211082458
#     y: 0.49385571479797363
#   }
#   relative_keypoints {
#     x: 0.48554620146751404
#     y: 0.6004133224487305
#   }
#   relative_keypoints {
#     x: 0.48795565962791443
#     y: 0.6979355216026306
#   }
#   relative_keypoints {
#     x: 0.3762400448322296
#     y: 0.5601819157600403
#   }
#   relative_keypoints {
#     x: 0.6011864542961121
#     y: 0.5463628768920898
#   }
# }
#
# 0 label_id: 0
# score: 0.9309623837471008
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3570585250854492
#     ymin: 0.3756757974624634
#     width: 0.25990748405456543
#     height: 0.4620566964149475
#   }
#   relative_keypoints {
#     x: 0.4322872757911682
#     y: 0.5014566779136658
#   }
#   relative_keypoints {
#     x: 0.538504421710968
#     y: 0.495217502117157
#   }
#   relative_keypoints {
#     x: 0.4857426881790161
#     y: 0.6022765040397644
#   }
#   relative_keypoints {
#     x: 0.48699891567230225
#     y: 0.7000206112861633
#   }
#   relative_keypoints {
#     x: 0.3736473619937897
#     y: 0.5565792918205261
#   }
#   relative_keypoints {
#     x: 0.5996120572090149
#     y: 0.54825758934021
#   }
# }
#
# 0 label_id: 0
# score: 0.9307880401611328
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3581372797489166
#     ymin: 0.37781572341918945
#     width: 0.25925830006599426
#     height: 0.46090275049209595
#   }
#   relative_keypoints {
#     x: 0.4330006539821625
#     y: 0.5017876029014587
#   }
#   relative_keypoints {
#     x: 0.5393120050430298
#     y: 0.495896577835083
#   }
#   relative_keypoints {
#     x: 0.4862019121646881
#     y: 0.6010048985481262
#   }
#   relative_keypoints {
#     x: 0.4872882664203644
#     y: 0.6997843384742737
#   }
#   relative_keypoints {
#     x: 0.3741956651210785
#     y: 0.5584497451782227
#   }
#   relative_keypoints {
#     x: 0.6004834771156311
#     y: 0.5513117909431458
#   }
# }
#
# 0 label_id: 0
# score: 0.9282177090644836
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35651445388793945
#     ymin: 0.37531763315200806
#     width: 0.2599836587905884
#     height: 0.462192177772522
#   }
#   relative_keypoints {
#     x: 0.4315342307090759
#     y: 0.5005488991737366
#   }
#   relative_keypoints {
#     x: 0.537963330745697
#     y: 0.4931301474571228
#   }
#   relative_keypoints {
#     x: 0.4851437211036682
#     y: 0.5997671484947205
#   }
#   relative_keypoints {
#     x: 0.48657774925231934
#     y: 0.6986189484596252
#   }
#   relative_keypoints {
#     x: 0.37317508459091187
#     y: 0.5576498508453369
#   }
#   relative_keypoints {
#     x: 0.5991520881652832
#     y: 0.5476996302604675
#   }
# }
#
# 0 label_id: 0
# score: 0.9242323040962219
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3546965718269348
#     ymin: 0.37527036666870117
#     width: 0.26016050577163696
#     height: 0.4625064730644226
#   }
#   relative_keypoints {
#     x: 0.43101218342781067
#     y: 0.5012213587760925
#   }
#   relative_keypoints {
#     x: 0.537344217300415
#     y: 0.49681520462036133
#   }
#   relative_keypoints {
#     x: 0.48479709029197693
#     y: 0.6039607524871826
#   }
#   relative_keypoints {
#     x: 0.4852208197116852
#     y: 0.7009305357933044
#   }
#   relative_keypoints {
#     x: 0.3711656630039215
#     y: 0.5535027384757996
#   }
#   relative_keypoints {
#     x: 0.5966902375221252
#     y: 0.5488831996917725
#   }
# }
#
# 0 label_id: 0
# score: 0.9211075901985168
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3567350208759308
#     ymin: 0.37742483615875244
#     width: 0.2577544152736664
#     height: 0.4582288861274719
#   }
#   relative_keypoints {
#     x: 0.43072643876075745
#     y: 0.5016862154006958
#   }
#   relative_keypoints {
#     x: 0.5365663766860962
#     y: 0.496224045753479
#   }
#   relative_keypoints {
#     x: 0.483519971370697
#     y: 0.6016945242881775
#   }
#   relative_keypoints {
#     x: 0.4846343398094177
#     y: 0.6991918683052063
#   }
#   relative_keypoints {
#     x: 0.37279728055000305
#     y: 0.5564701557159424
#   }
#   relative_keypoints {
#     x: 0.5972111225128174
#     y: 0.5496721267700195
#   }
# }
#
# 0 label_id: 0
# score: 0.9225114583969116
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.353546679019928
#     ymin: 0.3739739656448364
#     width: 0.25867515802383423
#     height: 0.4598662257194519
#   }
#   relative_keypoints {
#     x: 0.43251466751098633
#     y: 0.4955756664276123
#   }
#   relative_keypoints {
#     x: 0.5382832884788513
#     y: 0.4957277774810791
#   }
#   relative_keypoints {
#     x: 0.48698538541793823
#     y: 0.5990310311317444
#   }
#   relative_keypoints {
#     x: 0.4852575361728668
#     y: 0.6970945000648499
#   }
#   relative_keypoints {
#     x: 0.3690440058708191
#     y: 0.5479614734649658
#   }
#   relative_keypoints {
#     x: 0.5931133031845093
#     y: 0.5520690083503723
#   }
# }
#
# 0 label_id: 0
# score: 0.9196121096611023
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3525921702384949
#     ymin: 0.3727298974990845
#     width: 0.2614971995353699
#     height: 0.46488267183303833
#   }
#   relative_keypoints {
#     x: 0.4311993420124054
#     y: 0.4985826015472412
#   }
#   relative_keypoints {
#     x: 0.5376761555671692
#     y: 0.49699699878692627
#   }
#   relative_keypoints {
#     x: 0.4855671525001526
#     y: 0.6043621897697449
#   }
#   relative_keypoints {
#     x: 0.4847874045372009
#     y: 0.7015252709388733
#   }
#   relative_keypoints {
#     x: 0.36921632289886475
#     y: 0.5493132472038269
#   }
#   relative_keypoints {
#     x: 0.5947227478027344
#     y: 0.5496540069580078
#   }
# }
#
# 0 label_id: 0
# score: 0.9191828370094299
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35376256704330444
#     ymin: 0.37285202741622925
#     width: 0.26055407524108887
#     height: 0.4632061719894409
#   }
#   relative_keypoints {
#     x: 0.4307921528816223
#     y: 0.49839717149734497
#   }
#   relative_keypoints {
#     x: 0.5370020866394043
#     y: 0.49717628955841064
#   }
#   relative_keypoints {
#     x: 0.4838894009590149
#     y: 0.6044702529907227
#   }
#   relative_keypoints {
#     x: 0.48341548442840576
#     y: 0.7010045647621155
#   }
#   relative_keypoints {
#     x: 0.3705466091632843
#     y: 0.5474374294281006
#   }
#   relative_keypoints {
#     x: 0.5956878066062927
#     y: 0.5491924285888672
#   }
# }
#
# 0 label_id: 0
# score: 0.916942298412323
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35494333505630493
#     ymin: 0.37354397773742676
#     width: 0.2590383291244507
#     height: 0.4605115056037903
#   }
#   relative_keypoints {
#     x: 0.43175390362739563
#     y: 0.49774813652038574
#   }
#   relative_keypoints {
#     x: 0.5377683043479919
#     y: 0.4956199526786804
#   }
#   relative_keypoints {
#     x: 0.4855535924434662
#     y: 0.6010729670524597
#   }
#   relative_keypoints {
#     x: 0.48508578538894653
#     y: 0.6982384324073792
#   }
#   relative_keypoints {
#     x: 0.3708436191082001
#     y: 0.5496577024459839
#   }
#   relative_keypoints {
#     x: 0.5956389904022217
#     y: 0.5493346452713013
#   }
# }
#
# 0 label_id: 0
# score: 0.9209146499633789
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35317468643188477
#     ymin: 0.37112659215927124
#     width: 0.2608731985092163
#     height: 0.46377360820770264
#   }
#   relative_keypoints {
#     x: 0.43111181259155273
#     y: 0.49617552757263184
#   }
#   relative_keypoints {
#     x: 0.5376850962638855
#     y: 0.4957142472267151
#   }
#   relative_keypoints {
#     x: 0.48499637842178345
#     y: 0.6026951670646667
#   }
#   relative_keypoints {
#     x: 0.4839923679828644
#     y: 0.699704110622406
#   }
#   relative_keypoints {
#     x: 0.3694745898246765
#     y: 0.5458201169967651
#   }
#   relative_keypoints {
#     x: 0.5949908494949341
#     y: 0.5485202074050903
#   }
# }
#
# 0 label_id: 0
# score: 0.91849285364151
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3553573191165924
#     ymin: 0.3746124505996704
#     width: 0.2589382827281952
#     height: 0.4603336453437805
#   }
#   relative_keypoints {
#     x: 0.4301607310771942
#     y: 0.4988357424736023
#   }
#   relative_keypoints {
#     x: 0.5365908145904541
#     y: 0.4976084232330322
#   }
#   relative_keypoints {
#     x: 0.48245173692703247
#     y: 0.6034055352210999
#   }
#   relative_keypoints {
#     x: 0.48249462246894836
#     y: 0.7001772522926331
#   }
#   relative_keypoints {
#     x: 0.3715856075286865
#     y: 0.5490895509719849
#   }
#   relative_keypoints {
#     x: 0.596836268901825
#     y: 0.5503542423248291
#   }
# }
#
# 0 label_id: 0
# score: 0.9188979864120483
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36120009422302246
#     ymin: 0.37685626745224
#     width: 0.2590155005455017
#     height: 0.4604710340499878
#   }
#   relative_keypoints {
#     x: 0.4370400309562683
#     y: 0.4991517663002014
#   }
#   relative_keypoints {
#     x: 0.5425664186477661
#     y: 0.4966621994972229
#   }
#   relative_keypoints {
#     x: 0.48888128995895386
#     y: 0.6001403331756592
#   }
#   relative_keypoints {
#     x: 0.4892720878124237
#     y: 0.6995570063591003
#   }
#   relative_keypoints {
#     x: 0.3782358169555664
#     y: 0.5555143356323242
#   }
#   relative_keypoints {
#     x: 0.6032270789146423
#     y: 0.5544407367706299
#   }
# }
#
# 0 label_id: 0
# score: 0.9111036658287048
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36459222435951233
#     ymin: 0.38238096237182617
#     width: 0.2543829381465912
#     height: 0.45223528146743774
#   }
#   relative_keypoints {
#     x: 0.4391034245491028
#     y: 0.5014592409133911
#   }
#   relative_keypoints {
#     x: 0.5434409379959106
#     y: 0.4981444478034973
#   }
#   relative_keypoints {
#     x: 0.4909096956253052
#     y: 0.597680389881134
#   }
#   relative_keypoints {
#     x: 0.49141982197761536
#     y: 0.6965633034706116
#   }
#   relative_keypoints {
#     x: 0.38041889667510986
#     y: 0.5603998899459839
#   }
#   relative_keypoints {
#     x: 0.6027064919471741
#     y: 0.5578396320343018
#   }
# }
#
# 0 label_id: 0
# score: 0.91783607006073
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3555665910243988
#     ymin: 0.37360459566116333
#     width: 0.259056955575943
#     height: 0.4605448246002197
#   }
#   relative_keypoints {
#     x: 0.4319804906845093
#     y: 0.4997733235359192
#   }
#   relative_keypoints {
#     x: 0.5373753905296326
#     y: 0.4984186291694641
#   }
#   relative_keypoints {
#     x: 0.4847770035266876
#     y: 0.605828583240509
#   }
#   relative_keypoints {
#     x: 0.4844173192977905
#     y: 0.7011093497276306
#   }
#   relative_keypoints {
#     x: 0.372419536113739
#     y: 0.5477410554885864
#   }
#   relative_keypoints {
#     x: 0.5959968566894531
#     y: 0.5487836003303528
#   }
# }
#
# 0 label_id: 0
# score: 0.9235025644302368
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3468403220176697
#     ymin: 0.3759124279022217
#     width: 0.25687772035598755
#     height: 0.4566701054573059
#   }
#   relative_keypoints {
#     x: 0.4211350679397583
#     y: 0.5008615851402283
#   }
#   relative_keypoints {
#     x: 0.5259528160095215
#     y: 0.4915708899497986
#   }
#   relative_keypoints {
#     x: 0.47484254837036133
#     y: 0.5981595516204834
#   }
#   relative_keypoints {
#     x: 0.47622057795524597
#     y: 0.6953707337379456
#   }
#   relative_keypoints {
#     x: 0.36362984776496887
#     y: 0.5556974411010742
#   }
#   relative_keypoints {
#     x: 0.5862705707550049
#     y: 0.543488085269928
#   }
# }
# 0 label_id: 0
# score: 0.9254772067070007
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34311047196388245
#     ymin: 0.38911038637161255
#     width: 0.24766430258750916
#     height: 0.44029152393341064
#   }
#   relative_keypoints {
#     x: 0.4133187532424927
#     y: 0.5086892247200012
#   }
#   relative_keypoints {
#     x: 0.5140339732170105
#     y: 0.4879303574562073
#   }
#   relative_keypoints {
#     x: 0.46837738156318665
#     y: 0.5920749306678772
#   }
#   relative_keypoints {
#     x: 0.47225233912467957
#     y: 0.6919470429420471
#   }
#   relative_keypoints {
#     x: 0.3581704795360565
#     y: 0.5791173577308655
#   }
#   relative_keypoints {
#     x: 0.5731886625289917
#     y: 0.5416735410690308
#   }
# }
#
# 0 label_id: 0
# score: 0.9194720387458801
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3372249901294708
#     ymin: 0.38894474506378174
#     width: 0.2512917220592499
#     height: 0.4467394948005676
#   }
#   relative_keypoints {
#     x: 0.40898701548576355
#     y: 0.5125324726104736
#   }
#   relative_keypoints {
#     x: 0.5117962956428528
#     y: 0.49127197265625
#   }
#   relative_keypoints {
#     x: 0.4654528796672821
#     y: 0.5961693525314331
#   }
#   relative_keypoints {
#     x: 0.46957656741142273
#     y: 0.6969473958015442
#   }
#   relative_keypoints {
#     x: 0.3521936535835266
#     y: 0.5822377800941467
#   }
#   relative_keypoints {
#     x: 0.5714334845542908
#     y: 0.5439940690994263
#   }
# }
#
# 0 label_id: 0
# score: 0.9225549697875977
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33868589997291565
#     ymin: 0.38817888498306274
#     width: 0.24603036046028137
#     height: 0.43738603591918945
#   }
#   relative_keypoints {
#     x: 0.40361157059669495
#     y: 0.5098135471343994
#   }
#   relative_keypoints {
#     x: 0.5027022957801819
#     y: 0.4859498143196106
#   }
#   relative_keypoints {
#     x: 0.4536799490451813
#     y: 0.5891350507736206
#   }
#   relative_keypoints {
#     x: 0.45926743745803833
#     y: 0.6874189972877502
#   }
#   relative_keypoints {
#     x: 0.3562432527542114
#     y: 0.5792759656906128
#   }
#   relative_keypoints {
#     x: 0.5675085783004761
#     y: 0.541198194026947
#   }
# }
#
# 0 label_id: 0
# score: 0.9219944477081299
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33856743574142456
#     ymin: 0.3873679041862488
#     width: 0.24564367532730103
#     height: 0.4366987943649292
#   }
#   relative_keypoints {
#     x: 0.4037821590900421
#     y: 0.5107523798942566
#   }
#   relative_keypoints {
#     x: 0.5037150979042053
#     y: 0.48424625396728516
#   }
#   relative_keypoints {
#     x: 0.45644432306289673
#     y: 0.5887688398361206
#   }
#   relative_keypoints {
#     x: 0.46268171072006226
#     y: 0.6869276165962219
#   }
#   relative_keypoints {
#     x: 0.3547620475292206
#     y: 0.5812957286834717
#   }
#   relative_keypoints {
#     x: 0.567777156829834
#     y: 0.5360414981842041
#   }
# }
#
# 0 label_id: 0
# score: 0.9277029037475586
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34044381976127625
#     ymin: 0.39032894372940063
#     width: 0.24451705813407898
#     height: 0.4346961975097656
#   }
#   relative_keypoints {
#     x: 0.4078250527381897
#     y: 0.5121734142303467
#   }
#   relative_keypoints {
#     x: 0.5086631774902344
#     y: 0.4858405590057373
#   }
#   relative_keypoints {
#     x: 0.46376222372055054
#     y: 0.5914887189865112
#   }
#   relative_keypoints {
#     x: 0.46942734718322754
#     y: 0.6899747252464294
#   }
#   relative_keypoints {
#     x: 0.354549765586853
#     y: 0.5841290950775146
#   }
#   relative_keypoints {
#     x: 0.5692467093467712
#     y: 0.5350659489631653
#   }
# }
#
# 0 label_id: 0
# score: 0.9185563921928406
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3412553369998932
#     ymin: 0.3951858878135681
#     width: 0.24553921818733215
#     height: 0.43651342391967773
#   }
#   relative_keypoints {
#     x: 0.40746060013771057
#     y: 0.5130221843719482
#   }
#   relative_keypoints {
#     x: 0.5116021037101746
#     y: 0.4893801212310791
#   }
#   relative_keypoints {
#     x: 0.4636443257331848
#     y: 0.589543342590332
#   }
#   relative_keypoints {
#     x: 0.4691416919231415
#     y: 0.6910552382469177
#   }
#   relative_keypoints {
#     x: 0.3532932698726654
#     y: 0.5917121171951294
#   }
#   relative_keypoints {
#     x: 0.5739619731903076
#     y: 0.5474297404289246
#   }
# }
#
# 0 label_id: 0
# score: 0.9244871735572815
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34487393498420715
#     ymin: 0.3963252305984497
#     width: 0.24321767687797546
#     height: 0.43238621950149536
#   }
#   relative_keypoints {
#     x: 0.4090862274169922
#     y: 0.5130901336669922
#   }
#   relative_keypoints {
#     x: 0.5096968412399292
#     y: 0.49005019664764404
#   }
#   relative_keypoints {
#     x: 0.46188482642173767
#     y: 0.5894595384597778
#   }
#   relative_keypoints {
#     x: 0.46748486161231995
#     y: 0.6895087361335754
#   }
#   relative_keypoints {
#     x: 0.3583109676837921
#     y: 0.5873196125030518
#   }
#   relative_keypoints {
#     x: 0.5736527442932129
#     y: 0.5464050769805908
#   }
# }
#
# 0 label_id: 0
# score: 0.9229215979576111
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3432628810405731
#     ymin: 0.39199554920196533
#     width: 0.24541530013084412
#     height: 0.4362930655479431
#   }
#   relative_keypoints {
#     x: 0.41364333033561707
#     y: 0.5065220594406128
#   }
#   relative_keypoints {
#     x: 0.5147991180419922
#     y: 0.4894424080848694
#   }
#   relative_keypoints {
#     x: 0.46888986229896545
#     y: 0.587897539138794
#   }
#   relative_keypoints {
#     x: 0.4713684916496277
#     y: 0.6890131831169128
#   }
#   relative_keypoints {
#     x: 0.35565871000289917
#     y: 0.5787016749382019
#   }
#   relative_keypoints {
#     x: 0.5720550417900085
#     y: 0.5492427349090576
#   }
# }
#
# 0 label_id: 0
# score: 0.9196130037307739
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3415663242340088
#     ymin: 0.3768993020057678
#     width: 0.25294411182403564
#     height: 0.4496774673461914
#   }
#   relative_keypoints {
#     x: 0.4128772020339966
#     y: 0.5066904425621033
#   }
#   relative_keypoints {
#     x: 0.5140936374664307
#     y: 0.48426032066345215
#   }
#   relative_keypoints {
#     x: 0.4678148031234741
#     y: 0.5947047472000122
#   }
#   relative_keypoints {
#     x: 0.4724975526332855
#     y: 0.6915090680122375
#   }
#   relative_keypoints {
#     x: 0.3593117594718933
#     y: 0.5695569515228271
#   }
#   relative_keypoints {
#     x: 0.5754696726799011
#     y: 0.5301164984703064
#   }
# }
#
# 0 label_id: 0
# score: 0.9237656593322754
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.341693252325058
#     ymin: 0.3793568015098572
#     width: 0.25268223881721497
#     height: 0.4492119550704956
#   }
#   relative_keypoints {
#     x: 0.41312944889068604
#     y: 0.5066144466400146
#   }
#   relative_keypoints {
#     x: 0.5145534873008728
#     y: 0.4847375750541687
#   }
#   relative_keypoints {
#     x: 0.46790939569473267
#     y: 0.5926817655563354
#   }
#   relative_keypoints {
#     x: 0.4720609486103058
#     y: 0.6914168000221252
#   }
#   relative_keypoints {
#     x: 0.3589105010032654
#     y: 0.5726742148399353
#   }
#   relative_keypoints {
#     x: 0.5755513906478882
#     y: 0.53444904088974
#   }
# }
#
# 0 label_id: 0
# score: 0.9254812002182007
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34286928176879883
#     ymin: 0.3848532438278198
#     width: 0.2499982714653015
#     height: 0.44444018602371216
#   }
#   relative_keypoints {
#     x: 0.4136448800563812
#     y: 0.5073828101158142
#   }
#   relative_keypoints {
#     x: 0.5151078104972839
#     y: 0.4866732358932495
#   }
#   relative_keypoints {
#     x: 0.4684108793735504
#     y: 0.5898488163948059
#   }
#   relative_keypoints {
#     x: 0.47189053893089294
#     y: 0.6897850632667542
#   }
#   relative_keypoints {
#     x: 0.35807937383651733
#     y: 0.5767180919647217
#   }
#   relative_keypoints {
#     x: 0.5750099420547485
#     y: 0.5413710474967957
#   }
# }
#
# 0 label_id: 0
# score: 0.9223231077194214
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3412921130657196
#     ymin: 0.38673973083496094
#     width: 0.25000324845314026
#     height: 0.44444912672042847
#   }
#   relative_keypoints {
#     x: 0.41342175006866455
#     y: 0.5050423741340637
#   }
#   relative_keypoints {
#     x: 0.5151150226593018
#     y: 0.48899364471435547
#   }
#   relative_keypoints {
#     x: 0.4674205183982849
#     y: 0.5884128212928772
#   }
#   relative_keypoints {
#     x: 0.4691644012928009
#     y: 0.6902328133583069
#   }
#   relative_keypoints {
#     x: 0.3557349145412445
#     y: 0.5746111273765564
#   }
#   relative_keypoints {
#     x: 0.5732437968254089
#     y: 0.549610435962677
#   }
# }
#
# 0 label_id: 0
# score: 0.9232905507087708
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3409704864025116
#     ymin: 0.3831983804702759
#     width: 0.25116029381752014
#     height: 0.4465060830116272
#   }
#   relative_keypoints {
#     x: 0.41337060928344727
#     y: 0.502803385257721
#   }
#   relative_keypoints {
#     x: 0.5153042674064636
#     y: 0.4881059527397156
#   }
#   relative_keypoints {
#     x: 0.46697893738746643
#     y: 0.5893335342407227
#   }
#   relative_keypoints {
#     x: 0.4686523377895355
#     y: 0.690744936466217
#   }
#   relative_keypoints {
#     x: 0.35618871450424194
#     y: 0.5690535306930542
#   }
#   relative_keypoints {
#     x: 0.5738663673400879
#     y: 0.5461620688438416
#   }
# }
# 0 label_id: 0
# score: 0.9217521548271179
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34153732657432556
#     ymin: 0.384208083152771
#     width: 0.2502165734767914
#     height: 0.44482845067977905
#   }
#   relative_keypoints {
#     x: 0.4146648049354553
#     y: 0.5008852481842041
#   }
#   relative_keypoints {
#     x: 0.5164468884468079
#     y: 0.48751503229141235
#   }
#   relative_keypoints {
#     x: 0.4685715436935425
#     y: 0.5854463577270508
#   }
#   relative_keypoints {
#     x: 0.46954813599586487
#     y: 0.6879716515541077
#   }
#   relative_keypoints {
#     x: 0.3560889959335327
#     y: 0.5696916580200195
#   }
#   relative_keypoints {
#     x: 0.5735235214233398
#     y: 0.5496807098388672
#   }
# }
#
# 0 label_id: 0
# score: 0.9189682602882385
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3403327167034149
#     ymin: 0.38428544998168945
#     width: 0.25135329365730286
#     height: 0.4468492865562439
#   }
#   relative_keypoints {
#     x: 0.41333118081092834
#     y: 0.501720130443573
#   }
#   relative_keypoints {
#     x: 0.5153990387916565
#     y: 0.4883471131324768
#   }
#   relative_keypoints {
#     x: 0.4666403532028198
#     y: 0.5872061848640442
#   }
#   relative_keypoints {
#     x: 0.4677078127861023
#     y: 0.6899215579032898
#   }
#   relative_keypoints {
#     x: 0.3553214967250824
#     y: 0.5704562664031982
#   }
#   relative_keypoints {
#     x: 0.5732536911964417
#     y: 0.5509880781173706
#   }
# }
#
# 0 label_id: 0
# score: 0.9272204637527466
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34104326367378235
#     ymin: 0.38553720712661743
#     width: 0.25157734751701355
#     height: 0.44724762439727783
#   }
#   relative_keypoints {
#     x: 0.414867639541626
#     y: 0.5022101998329163
#   }
#   relative_keypoints {
#     x: 0.5172995328903198
#     y: 0.4875437617301941
#   }
#   relative_keypoints {
#     x: 0.4696272611618042
#     y: 0.5856401920318604
#   }
#   relative_keypoints {
#     x: 0.47074928879737854
#     y: 0.689343273639679
#   }
#   relative_keypoints {
#     x: 0.3554299771785736
#     y: 0.5738804936408997
#   }
#   relative_keypoints {
#     x: 0.5743416547775269
#     y: 0.5515429377555847
#   }
# }
#
# 0 label_id: 0
# score: 0.9235663414001465
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34094956517219543
#     ymin: 0.3838012218475342
#     width: 0.2513849437236786
#     height: 0.4469054341316223
#   }
#   relative_keypoints {
#     x: 0.41352373361587524
#     y: 0.50313800573349
#   }
#   relative_keypoints {
#     x: 0.5160017013549805
#     y: 0.48814356327056885
#   }
#   relative_keypoints {
#     x: 0.46759748458862305
#     y: 0.5888348817825317
#   }
#   relative_keypoints {
#     x: 0.46928495168685913
#     y: 0.6904948353767395
#   }
#   relative_keypoints {
#     x: 0.35581105947494507
#     y: 0.5709664821624756
#   }
#   relative_keypoints {
#     x: 0.5743503570556641
#     y: 0.547514796257019
#   }
# }
#
# 0 label_id: 0
# score: 0.923984944820404
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3409154415130615
#     ymin: 0.3852570056915283
#     width: 0.2515043616294861
#     height: 0.44711774587631226
#   }
#   relative_keypoints {
#     x: 0.4135207235813141
#     y: 0.5050013661384583
#   }
#   relative_keypoints {
#     x: 0.5154874920845032
#     y: 0.48901915550231934
#   }
#   relative_keypoints {
#     x: 0.4672960638999939
#     y: 0.5900098085403442
#   }
#   relative_keypoints {
#     x: 0.46912088990211487
#     y: 0.6917238831520081
#   }
#   relative_keypoints {
#     x: 0.3561735153198242
#     y: 0.5735605955123901
#   }
#   relative_keypoints {
#     x: 0.5739796757698059
#     y: 0.5484790802001953
#   }
# }
#
# 0 label_id: 0
# score: 0.9254307746887207
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3400968015193939
#     ymin: 0.38361233472824097
#     width: 0.25230279564857483
#     height: 0.44853711128234863
#   }
#   relative_keypoints {
#     x: 0.4137616455554962
#     y: 0.504608690738678
#   }
#   relative_keypoints {
#     x: 0.515947163105011
#     y: 0.4893431067466736
#   }
#   relative_keypoints {
#     x: 0.4683310389518738
#     y: 0.5919677019119263
#   }
#   relative_keypoints {
#     x: 0.4699373245239258
#     y: 0.6929197907447815
#   }
#   relative_keypoints {
#     x: 0.35539692640304565
#     y: 0.571087121963501
#   }
#   relative_keypoints {
#     x: 0.5736167430877686
#     y: 0.5468795299530029
#   }
# }

# %%
face_detection()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 0 label_id: 0
# score: 0.9271814227104187
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3253106474876404
#     ymin: 0.32956749200820923
#     width: 0.32262295484542847
#     height: 0.43013161420822144
#   }
#   relative_keypoints {
#     x: 0.4023461937904358
#     y: 0.4162885546684265
#   }
#   relative_keypoints {
#     x: 0.5423909425735474
#     y: 0.40778648853302
#   }
#   relative_keypoints {
#     x: 0.4627627432346344
#     y: 0.4831891655921936
#   }
#   relative_keypoints {
#     x: 0.4677661061286926
#     y: 0.5996952056884766
#   }
#   relative_keypoints {
#     x: 0.34041839838027954
#     y: 0.5082578659057617
#   }
#   relative_keypoints {
#     x: 0.6367819309234619
#     y: 0.5015117526054382
#   }
# }
#
# 0 label_id: 0
# score: 0.931221604347229
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3288218677043915
#     ymin: 0.3305826187133789
#     width: 0.3210882842540741
#     height: 0.42808443307876587
#   }
#   relative_keypoints {
#     x: 0.4058367908000946
#     y: 0.41363638639450073
#   }
#   relative_keypoints {
#     x: 0.5465797185897827
#     y: 0.4051458239555359
#   }
#   relative_keypoints {
#     x: 0.46719396114349365
#     y: 0.47636765241622925
#   }
#   relative_keypoints {
#     x: 0.47157713770866394
#     y: 0.5951196551322937
#   }
#   relative_keypoints {
#     x: 0.34204262495040894
#     y: 0.5103440284729004
#   }
#   relative_keypoints {
#     x: 0.6400024890899658
#     y: 0.5039538741111755
#   }
# }
#
# 0 label_id: 0
# score: 0.9366986155509949
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3354661762714386
#     ymin: 0.32603955268859863
#     width: 0.3202907145023346
#     height: 0.42702460289001465
#   }
#   relative_keypoints {
#     x: 0.410571813583374
#     y: 0.4078168272972107
#   }
#   relative_keypoints {
#     x: 0.5502034425735474
#     y: 0.3985521197319031
#   }
#   relative_keypoints {
#     x: 0.4705401360988617
#     y: 0.46775370836257935
#   }
#   relative_keypoints {
#     x: 0.4756670296192169
#     y: 0.5865833163261414
#   }
#   relative_keypoints {
#     x: 0.34890371561050415
#     y: 0.508216142654419
#   }
#   relative_keypoints {
#     x: 0.6455764770507812
#     y: 0.5006073117256165
#   }
# }
#
# 0 label_id: 0
# score: 0.9304889440536499
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3354332149028778
#     ymin: 0.31879961490631104
#     width: 0.32121768593788147
#     height: 0.4282606840133667
#   }
#   relative_keypoints {
#     x: 0.4122612774372101
#     y: 0.39962702989578247
#   }
#   relative_keypoints {
#     x: 0.5529749393463135
#     y: 0.3938232660293579
#   }
#   relative_keypoints {
#     x: 0.47203755378723145
#     y: 0.46110355854034424
#   }
#   relative_keypoints {
#     x: 0.4754481315612793
#     y: 0.5800859928131104
#   }
#   relative_keypoints {
#     x: 0.3481576442718506
#     y: 0.4979131817817688
#   }
#   relative_keypoints {
#     x: 0.6465446949005127
#     y: 0.4978625178337097
#   }
# }
#
# 0 label_id: 0
# score: 0.9210638403892517
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34091877937316895
#     ymin: 0.3249477744102478
#     width: 0.3147451877593994
#     height: 0.41963106393814087
#   }
#   relative_keypoints {
#     x: 0.41697123646736145
#     y: 0.3983631730079651
#   }
#   relative_keypoints {
#     x: 0.5570999383926392
#     y: 0.39340299367904663
#   }
#   relative_keypoints {
#     x: 0.47696834802627563
#     y: 0.45141518115997314
#   }
#   relative_keypoints {
#     x: 0.47931408882141113
#     y: 0.5732387900352478
#   }
#   relative_keypoints {
#     x: 0.3508811295032501
#     y: 0.5042517781257629
#   }
#   relative_keypoints {
#     x: 0.6486169099807739
#     y: 0.5069072246551514
#   }
# }
#
# 0 label_id: 0
# score: 0.9325448870658875
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.353091835975647
#     ymin: 0.3311886191368103
#     width: 0.3025071620941162
#     height: 0.40331220626831055
#   }
#   relative_keypoints {
#     x: 0.42495810985565186
#     y: 0.3997967839241028
#   }
#   relative_keypoints {
#     x: 0.5599419474601746
#     y: 0.39801162481307983
#   }
#   relative_keypoints {
#     x: 0.48032447695732117
#     y: 0.4516991972923279
#   }
#   relative_keypoints {
#     x: 0.4817555844783783
#     y: 0.5692731738090515
#   }
#   relative_keypoints {
#     x: 0.36236363649368286
#     y: 0.5019273161888123
#   }
#   relative_keypoints {
#     x: 0.6497944593429565
#     y: 0.511326789855957
#   }
# }
#
# 0 label_id: 0
# score: 0.9186403751373291
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35794711112976074
#     ymin: 0.3325073719024658
#     width: 0.29924947023391724
#     height: 0.3989675045013428
#   }
#   relative_keypoints {
#     x: 0.43011215329170227
#     y: 0.39874523878097534
#   }
#   relative_keypoints {
#     x: 0.5646844506263733
#     y: 0.3952871561050415
#   }
#   relative_keypoints {
#     x: 0.48740091919898987
#     y: 0.4463183283805847
#   }
#   relative_keypoints {
#     x: 0.489326536655426
#     y: 0.5651033520698547
#   }
#   relative_keypoints {
#     x: 0.3663892447948456
#     y: 0.5062246322631836
#   }
#   relative_keypoints {
#     x: 0.6519513130187988
#     y: 0.5112277865409851
#   }
# }
#
# 0 label_id: 0
# score: 0.9448580741882324
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3632938265800476
#     ymin: 0.33146053552627563
#     width: 0.29804766178131104
#     height: 0.3973786234855652
#   }
#   relative_keypoints {
#     x: 0.43239763379096985
#     y: 0.39292818307876587
#   }
#   relative_keypoints {
#     x: 0.5691922903060913
#     y: 0.394764244556427
#   }
#   relative_keypoints {
#     x: 0.4857963025569916
#     y: 0.4386768937110901
#   }
#   relative_keypoints {
#     x: 0.48599278926849365
#     y: 0.5584795475006104
#   }
#   relative_keypoints {
#     x: 0.37017276883125305
#     y: 0.49891477823257446
#   }
#   relative_keypoints {
#     x: 0.6579349637031555
#     y: 0.5175098776817322
#   }
# }
#
# 0 label_id: 0
# score: 0.9373881816864014
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3635360896587372
#     ymin: 0.32987022399902344
#     width: 0.2998327910900116
#     height: 0.3997555375099182
#   }
#   relative_keypoints {
#     x: 0.4375518560409546
#     y: 0.3936607241630554
#   }
#   relative_keypoints {
#     x: 0.5728996992111206
#     y: 0.3983227610588074
#   }
#   relative_keypoints {
#     x: 0.4920412302017212
#     y: 0.4487343430519104
#   }
#   relative_keypoints {
#     x: 0.49015384912490845
#     y: 0.5657532215118408
#   }
#   relative_keypoints {
#     x: 0.37220174074172974
#     y: 0.49229395389556885
#   }
#   relative_keypoints {
#     x: 0.6569268107414246
#     y: 0.5157492160797119
#   }
# }
#
# 0 label_id: 0
# score: 0.9416395425796509
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372429221868515
#     ymin: 0.32787030935287476
#     width: 0.29648807644844055
#     height: 0.39530038833618164
#   }
#   relative_keypoints {
#     x: 0.44497671723365784
#     y: 0.39719635248184204
#   }
#   relative_keypoints {
#     x: 0.5742097496986389
#     y: 0.4040478467941284
#   }
#   relative_keypoints {
#     x: 0.49195006489753723
#     y: 0.45789438486099243
#   }
#   relative_keypoints {
#     x: 0.49059829115867615
#     y: 0.5681397318840027
#   }
#   relative_keypoints {
#     x: 0.387346088886261
#     y: 0.4826214909553528
#   }
#   relative_keypoints {
#     x: 0.6599185466766357
#     y: 0.511224091053009
#   }
# }
#
# 0 label_id: 0
# score: 0.9514160752296448
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37306734919548035
#     ymin: 0.3302534818649292
#     width: 0.2969408929347992
#     height: 0.3959048390388489
#   }
#   relative_keypoints {
#     x: 0.44779834151268005
#     y: 0.3960535526275635
#   }
#   relative_keypoints {
#     x: 0.5795645713806152
#     y: 0.4046863317489624
#   }
#   relative_keypoints {
#     x: 0.4984261989593506
#     y: 0.453189492225647
#   }
#   relative_keypoints {
#     x: 0.4955666661262512
#     y: 0.5659831166267395
#   }
#   relative_keypoints {
#     x: 0.384512722492218
#     y: 0.48639029264450073
#   }
#   relative_keypoints {
#     x: 0.6621831655502319
#     y: 0.5174193382263184
#   }
# }
#
# 0 label_id: 0
# score: 0.9464176893234253
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37593480944633484
#     ymin: 0.33008313179016113
#     width: 0.29552045464515686
#     height: 0.3940131664276123
#   }
#   relative_keypoints {
#     x: 0.44697484374046326
#     y: 0.39357858896255493
#   }
#   relative_keypoints {
#     x: 0.5809401869773865
#     y: 0.40135639905929565
#   }
#   relative_keypoints {
#     x: 0.4983717203140259
#     y: 0.44772130250930786
#   }
#   relative_keypoints {
#     x: 0.49699583649635315
#     y: 0.5623729825019836
#   }
#   relative_keypoints {
#     x: 0.3855166435241699
#     y: 0.48711103200912476
#   }
#   relative_keypoints {
#     x: 0.6665031909942627
#     y: 0.5153920650482178
#   }
# }
#
# 0 label_id: 0
# score: 0.9487817287445068
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3802143633365631
#     ymin: 0.332977294921875
#     width: 0.29218509793281555
#     height: 0.3895636200904846
#   }
#   relative_keypoints {
#     x: 0.4464138150215149
#     y: 0.3945925831794739
#   }
#   relative_keypoints {
#     x: 0.5807284712791443
#     y: 0.40182173252105713
#   }
#   relative_keypoints {
#     x: 0.4953274428844452
#     y: 0.4479990601539612
#   }
#   relative_keypoints {
#     x: 0.49492529034614563
#     y: 0.5619993805885315
#   }
#   relative_keypoints {
#     x: 0.3893190622329712
#     y: 0.489102840423584
#   }
#   relative_keypoints {
#     x: 0.6702198386192322
#     y: 0.5180163383483887
#   }
# }
#
# 0 label_id: 0
# score: 0.9562547206878662
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38234224915504456
#     ymin: 0.33003050088882446
#     width: 0.2942374050617218
#     height: 0.3923014998435974
#   }
#   relative_keypoints {
#     x: 0.44980257749557495
#     y: 0.39474666118621826
#   }
#   relative_keypoints {
#     x: 0.5834319591522217
#     y: 0.4038340449333191
#   }
#   relative_keypoints {
#     x: 0.49775105714797974
#     y: 0.4540495276451111
#   }
#   relative_keypoints {
#     x: 0.49668386578559875
#     y: 0.5653154253959656
#   }
#   relative_keypoints {
#     x: 0.3924793303012848
#     y: 0.4824814200401306
#   }
#   relative_keypoints {
#     x: 0.672561764717102
#     y: 0.5151570439338684
#   }
# }
# 0 label_id: 0
# score: 0.9453597068786621
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3865330219268799
#     ymin: 0.33035701513290405
#     width: 0.29070770740509033
#     height: 0.38759541511535645
#   }
#   relative_keypoints {
#     x: 0.45299097895622253
#     y: 0.39573872089385986
#   }
#   relative_keypoints {
#     x: 0.5838332176208496
#     y: 0.4057324528694153
#   }
#   relative_keypoints {
#     x: 0.4984724521636963
#     y: 0.45727211236953735
#   }
#   relative_keypoints {
#     x: 0.4977084696292877
#     y: 0.566087007522583
#   }
#   relative_keypoints {
#     x: 0.3983718454837799
#     y: 0.4788907766342163
#   }
#   relative_keypoints {
#     x: 0.6729246973991394
#     y: 0.5128636956214905
#   }
# }
#
# 0 label_id: 0
# score: 0.9380156397819519
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3877442181110382
#     ymin: 0.33086103200912476
#     width: 0.28937599062919617
#     height: 0.38581979274749756
#   }
#   relative_keypoints {
#     x: 0.4555748403072357
#     y: 0.3964686989784241
#   }
#   relative_keypoints {
#     x: 0.5863807797431946
#     y: 0.4056190848350525
#   }
#   relative_keypoints {
#     x: 0.5039166808128357
#     y: 0.4570225477218628
#   }
#   relative_keypoints {
#     x: 0.5032556653022766
#     y: 0.5657015442848206
#   }
#   relative_keypoints {
#     x: 0.39816921949386597
#     y: 0.47990548610687256
#   }
#   relative_keypoints {
#     x: 0.672679603099823
#     y: 0.5103195309638977
#   }
# }
#
# 0 label_id: 0
# score: 0.937807023525238
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3878993093967438
#     ymin: 0.3287627100944519
#     width: 0.29314950108528137
#     height: 0.39085060358047485
#   }
#   relative_keypoints {
#     x: 0.45697787404060364
#     y: 0.39467328786849976
#   }
#   relative_keypoints {
#     x: 0.5906414985656738
#     y: 0.40021294355392456
#   }
#   relative_keypoints {
#     x: 0.5093210935592651
#     y: 0.45167070627212524
#   }
#   relative_keypoints {
#     x: 0.5098285675048828
#     y: 0.563708484172821
#   }
#   relative_keypoints {
#     x: 0.3972470164299011
#     y: 0.4850921034812927
#   }
#   relative_keypoints {
#     x: 0.6770851016044617
#     y: 0.507499635219574
#   }
# }
#
# 0 label_id: 0
# score: 0.9433380365371704
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3990676999092102
#     ymin: 0.3287566900253296
#     width: 0.2919374108314514
#     height: 0.38923412561416626
#   }
#   relative_keypoints {
#     x: 0.466708242893219
#     y: 0.38698410987854004
#   }
#   relative_keypoints {
#     x: 0.6016877293586731
#     y: 0.3989725112915039
#   }
#   relative_keypoints {
#     x: 0.5165148377418518
#     y: 0.4411962628364563
#   }
#   relative_keypoints {
#     x: 0.514692485332489
#     y: 0.5566561818122864
#   }
#   relative_keypoints {
#     x: 0.404643177986145
#     y: 0.4804951548576355
#   }
#   relative_keypoints {
#     x: 0.6887899041175842
#     y: 0.5160443186759949
#   }
# }
#
# 0 label_id: 0
# score: 0.9407000541687012
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39910703897476196
#     ymin: 0.3286113142967224
#     width: 0.2956252098083496
#     height: 0.39415109157562256
#   }
#   relative_keypoints {
#     x: 0.4693777859210968
#     y: 0.39002686738967896
#   }
#   relative_keypoints {
#     x: 0.6052618622779846
#     y: 0.39956170320510864
#   }
#   relative_keypoints {
#     x: 0.5221127271652222
#     y: 0.445331871509552
#   }
#   relative_keypoints {
#     x: 0.5204221606254578
#     y: 0.5611331462860107
#   }
#   relative_keypoints {
#     x: 0.40449395775794983
#     y: 0.4840705990791321
#   }
#   relative_keypoints {
#     x: 0.6907455921173096
#     y: 0.5141807198524475
#   }
# }
#
# 0 label_id: 0
# score: 0.9506528973579407
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39811623096466064
#     ymin: 0.3254202604293823
#     width: 0.29902148246765137
#     height: 0.39868438243865967
#   }
#   relative_keypoints {
#     x: 0.472927987575531
#     y: 0.39322006702423096
#   }
#   relative_keypoints {
#     x: 0.6080464720726013
#     y: 0.4027705192565918
#   }
#   relative_keypoints {
#     x: 0.5279538035392761
#     y: 0.4531153440475464
#   }
#   relative_keypoints {
#     x: 0.5249913930892944
#     y: 0.5646515488624573
#   }
#   relative_keypoints {
#     x: 0.40455231070518494
#     y: 0.48237401247024536
#   }
#   relative_keypoints {
#     x: 0.6900462508201599
#     y: 0.5125711560249329
#   }
# }
#
# 0 label_id: 0
# score: 0.9522271752357483
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40471306443214417
#     ymin: 0.32751405239105225
#     width: 0.29742535948753357
#     height: 0.39655452966690063
#   }
#   relative_keypoints {
#     x: 0.47552767395973206
#     y: 0.3946111798286438
#   }
#   relative_keypoints {
#     x: 0.6104629635810852
#     y: 0.40061938762664795
#   }
#   relative_keypoints {
#     x: 0.530146062374115
#     y: 0.45129042863845825
#   }
#   relative_keypoints {
#     x: 0.5289290547370911
#     y: 0.5637102723121643
#   }
#   relative_keypoints {
#     x: 0.4103013575077057
#     y: 0.4877817630767822
#   }
#   relative_keypoints {
#     x: 0.6958747506141663
#     y: 0.5111708045005798
#   }
# }
#
# 0 label_id: 0
# score: 0.9483118057250977
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40734240412712097
#     ymin: 0.3280044198036194
#     width: 0.2961452305316925
#     height: 0.3948476314544678
#   }
#   relative_keypoints {
#     x: 0.47950315475463867
#     y: 0.3945855498313904
#   }
#   relative_keypoints {
#     x: 0.6130611896514893
#     y: 0.4014546275138855
#   }
#   relative_keypoints {
#     x: 0.5336602926254272
#     y: 0.4517485499382019
#   }
#   relative_keypoints {
#     x: 0.5317654609680176
#     y: 0.5635761618614197
#   }
#   relative_keypoints {
#     x: 0.4135259985923767
#     y: 0.48693978786468506
#   }
#   relative_keypoints {
#     x: 0.6964691877365112
#     y: 0.5119433403015137
#   }
# }
#
# 0 label_id: 0
# score: 0.9430681467056274
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40449830889701843
#     ymin: 0.327555775642395
#     width: 0.2984427511692047
#     height: 0.3979131579399109
#   }
#   relative_keypoints {
#     x: 0.4822915196418762
#     y: 0.39560753107070923
#   }
#   relative_keypoints {
#     x: 0.6163264513015747
#     y: 0.3980869650840759
#   }
#   relative_keypoints {
#     x: 0.5421085357666016
#     y: 0.4476011395454407
#   }
#   relative_keypoints {
#     x: 0.5405277013778687
#     y: 0.5615665316581726
#   }
#   relative_keypoints {
#     x: 0.4106142520904541
#     y: 0.49332892894744873
#   }
#   relative_keypoints {
#     x: 0.6947609186172485
#     y: 0.5082911849021912
#   }
# }
#
# 0 label_id: 0
# score: 0.9353790879249573
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4046389162540436
#     ymin: 0.328976035118103
#     width: 0.29896190762519836
#     height: 0.39860427379608154
#   }
#   relative_keypoints {
#     x: 0.4854375422000885
#     y: 0.396634042263031
#   }
#   relative_keypoints {
#     x: 0.6201500296592712
#     y: 0.40099412202835083
#   }
#   relative_keypoints {
#     x: 0.5471112132072449
#     y: 0.44959551095962524
#   }
#   relative_keypoints {
#     x: 0.5441073179244995
#     y: 0.5640174746513367
#   }
#   relative_keypoints {
#     x: 0.4100296199321747
#     y: 0.49373167753219604
#   }
#   relative_keypoints {
#     x: 0.6950536966323853
#     y: 0.5114608407020569
#   }
# }
#
# 0 label_id: 0
# score: 0.9262027144432068
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4096832573413849
#     ymin: 0.3326459527015686
#     width: 0.29478171467781067
#     height: 0.39302873611450195
#   }
#   relative_keypoints {
#     x: 0.4885103404521942
#     y: 0.3988620638847351
#   }
#   relative_keypoints {
#     x: 0.621401309967041
#     y: 0.40488672256469727
#   }
#   relative_keypoints {
#     x: 0.5482058525085449
#     y: 0.452690064907074
#   }
#   relative_keypoints {
#     x: 0.5446996092796326
#     y: 0.5653404593467712
#   }
#   relative_keypoints {
#     x: 0.4144192039966583
#     y: 0.4936046004295349
#   }
#   relative_keypoints {
#     x: 0.6959440112113953
#     y: 0.5146193504333496
#   }
# }
#
# 0 label_id: 0
# score: 0.9252318143844604
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41309601068496704
#     ymin: 0.33469241857528687
#     width: 0.2935863733291626
#     height: 0.3914358615875244
#   }
#   relative_keypoints {
#     x: 0.4915156960487366
#     y: 0.3995291590690613
#   }
#   relative_keypoints {
#     x: 0.6238946914672852
#     y: 0.4056348204612732
#   }
#   relative_keypoints {
#     x: 0.550780177116394
#     y: 0.45162421464920044
#   }
#   relative_keypoints {
#     x: 0.5471271276473999
#     y: 0.5648503303527832
#   }
#   relative_keypoints {
#     x: 0.4175099730491638
#     y: 0.4962235689163208
#   }
#   relative_keypoints {
#     x: 0.6983271241188049
#     y: 0.5177443027496338
#   }
# }
#
# 0 label_id: 0
# score: 0.9227369427680969
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41590744256973267
#     ymin: 0.34135347604751587
#     width: 0.2910018563270569
#     height: 0.38799089193344116
#   }
#   relative_keypoints {
#     x: 0.4921328127384186
#     y: 0.398837149143219
#   }
#   relative_keypoints {
#     x: 0.6261321306228638
#     y: 0.40537506341934204
#   }
#   relative_keypoints {
#     x: 0.551457941532135
#     y: 0.4425063729286194
#   }
#   relative_keypoints {
#     x: 0.5476232767105103
#     y: 0.5602872967720032
#   }
#   relative_keypoints {
#     x: 0.4174734354019165
#     y: 0.5050519108772278
#   }
#   relative_keypoints {
#     x: 0.7017846703529358
#     y: 0.5280800461769104
#   }
# }
# 0 label_id: 0
# score: 0.9289237856864929
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4206918478012085
#     ymin: 0.34371596574783325
#     width: 0.28872936964035034
#     height: 0.3849611282348633
#   }
#   relative_keypoints {
#     x: 0.49369630217552185
#     y: 0.3991166353225708
#   }
#   relative_keypoints {
#     x: 0.6268378496170044
#     y: 0.4071177840232849
#   }
#   relative_keypoints {
#     x: 0.5497328042984009
#     y: 0.4420766830444336
#   }
#   relative_keypoints {
#     x: 0.5460954308509827
#     y: 0.5597450733184814
#   }
#   relative_keypoints {
#     x: 0.4223311245441437
#     y: 0.505426824092865
#   }
#   relative_keypoints {
#     x: 0.7053145170211792
#     y: 0.532294511795044
#   }
# }
#
# 0 label_id: 0
# score: 0.9336888790130615
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4240449070930481
#     ymin: 0.3418615460395813
#     width: 0.28878140449523926
#     height: 0.38502997159957886
#   }
#   relative_keypoints {
#     x: 0.495840460062027
#     y: 0.39827585220336914
#   }
#   relative_keypoints {
#     x: 0.6281432509422302
#     y: 0.4060831665992737
#   }
#   relative_keypoints {
#     x: 0.5499579906463623
#     y: 0.44354337453842163
#   }
#   relative_keypoints {
#     x: 0.5467618703842163
#     y: 0.5603490471839905
#   }
#   relative_keypoints {
#     x: 0.42679545283317566
#     y: 0.501910388469696
#   }
#   relative_keypoints {
#     x: 0.7082151770591736
#     y: 0.5290613770484924
#   }
# }
#
# 0 label_id: 0
# score: 0.9313198328018188
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42531391978263855
#     ymin: 0.33665066957473755
#     width: 0.2896360456943512
#     height: 0.386168897151947
#   }
#   relative_keypoints {
#     x: 0.49813443422317505
#     y: 0.3945523500442505
#   }
#   relative_keypoints {
#     x: 0.630405604839325
#     y: 0.4054204821586609
#   }
#   relative_keypoints {
#     x: 0.5510309934616089
#     y: 0.44550377130508423
#   }
#   relative_keypoints {
#     x: 0.5469070076942444
#     y: 0.5606915354728699
#   }
#   relative_keypoints {
#     x: 0.42927443981170654
#     y: 0.49202728271484375
#   }
#   relative_keypoints {
#     x: 0.7098727226257324
#     y: 0.5255261063575745
#   }
# }
#
# 0 label_id: 0
# score: 0.9348027110099792
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4255487620830536
#     ymin: 0.33394283056259155
#     width: 0.2932601273059845
#     height: 0.3909999132156372
#   }
#   relative_keypoints {
#     x: 0.4986409842967987
#     y: 0.39446473121643066
#   }
#   relative_keypoints {
#     x: 0.6321435570716858
#     y: 0.40677589178085327
#   }
#   relative_keypoints {
#     x: 0.5510256886482239
#     y: 0.4508208632469177
#   }
#   relative_keypoints {
#     x: 0.5469458699226379
#     y: 0.5653168559074402
#   }
#   relative_keypoints {
#     x: 0.4306879937648773
#     y: 0.48809105157852173
#   }
#   relative_keypoints {
#     x: 0.7133795619010925
#     y: 0.5242006182670593
#   }
# }
#
# 0 label_id: 0
# score: 0.9267708659172058
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4249056279659271
#     ymin: 0.332441508769989
#     width: 0.29627546668052673
#     height: 0.3950195908546448
#   }
#   relative_keypoints {
#     x: 0.5020235776901245
#     y: 0.39370787143707275
#   }
#   relative_keypoints {
#     x: 0.6368401646614075
#     y: 0.40757864713668823
#   }
#   relative_keypoints {
#     x: 0.5570526719093323
#     y: 0.45216166973114014
#   }
#   relative_keypoints {
#     x: 0.5517171025276184
#     y: 0.5672867298126221
#   }
#   relative_keypoints {
#     x: 0.4295746982097626
#     y: 0.4868745803833008
#   }
#   relative_keypoints {
#     x: 0.7148296236991882
#     y: 0.5245581269264221
#   }
# }
#
# 0 label_id: 0
# score: 0.9340232014656067
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42546504735946655
#     ymin: 0.33128929138183594
#     width: 0.29647237062454224
#     height: 0.39528292417526245
#   }
#   relative_keypoints {
#     x: 0.5051634907722473
#     y: 0.3933482766151428
#   }
#   relative_keypoints {
#     x: 0.6390596628189087
#     y: 0.40768104791641235
#   }
#   relative_keypoints {
#     x: 0.5615637898445129
#     y: 0.4533378481864929
#   }
#   relative_keypoints {
#     x: 0.5552617907524109
#     y: 0.5674657225608826
#   }
#   relative_keypoints {
#     x: 0.42975685000419617
#     y: 0.48494642972946167
#   }
#   relative_keypoints {
#     x: 0.7137686610221863
#     y: 0.5229434967041016
#   }
# }
#
# 0 label_id: 0
# score: 0.9340918660163879
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4265097975730896
#     ymin: 0.3323832154273987
#     width: 0.2955479025840759
#     height: 0.3940505385398865
#   }
#   relative_keypoints {
#     x: 0.5067033171653748
#     y: 0.3928203582763672
#   }
#   relative_keypoints {
#     x: 0.6409071087837219
#     y: 0.40861976146698
#   }
#   relative_keypoints {
#     x: 0.5635422468185425
#     y: 0.4519816040992737
#   }
#   relative_keypoints {
#     x: 0.5563666820526123
#     y: 0.5664019584655762
#   }
#   relative_keypoints {
#     x: 0.429610013961792
#     y: 0.4848645329475403
#   }
#   relative_keypoints {
#     x: 0.7144520878791809
#     y: 0.5256883502006531
#   }
# }
#
# 0 label_id: 0
# score: 0.9290398359298706
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42474839091300964
#     ymin: 0.33198755979537964
#     width: 0.2968432605266571
#     height: 0.3957746624946594
#   }
#   relative_keypoints {
#     x: 0.5053077936172485
#     y: 0.39214009046554565
#   }
#   relative_keypoints {
#     x: 0.6412081718444824
#     y: 0.4083234667778015
#   }
#   relative_keypoints {
#     x: 0.5633054375648499
#     y: 0.4508782625198364
#   }
#   relative_keypoints {
#     x: 0.5554517507553101
#     y: 0.5664804577827454
#   }
#   relative_keypoints {
#     x: 0.42688649892807007
#     y: 0.48486584424972534
#   }
#   relative_keypoints {
#     x: 0.7139604091644287
#     y: 0.52711421251297
#   }
# }
#
# 0 label_id: 0
# score: 0.9367698431015015
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4252051115036011
#     ymin: 0.32851165533065796
#     width: 0.3006114959716797
#     height: 0.40080153942108154
#   }
#   relative_keypoints {
#     x: 0.5058154463768005
#     y: 0.38970834016799927
#   }
#   relative_keypoints {
#     x: 0.6429697275161743
#     y: 0.4056212902069092
#   }
#   relative_keypoints {
#     x: 0.562933087348938
#     y: 0.44708770513534546
#   }
#   relative_keypoints {
#     x: 0.5554024577140808
#     y: 0.5644063353538513
#   }
#   relative_keypoints {
#     x: 0.42886611819267273
#     y: 0.483629047870636
#   }
#   relative_keypoints {
#     x: 0.7179172039031982
#     y: 0.525801420211792
#   }
# }
#
# 0 label_id: 0
# score: 0.9291245937347412
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4249385893344879
#     ymin: 0.3312501311302185
#     width: 0.2980291545391083
#     height: 0.39735591411590576
#   }
#   relative_keypoints {
#     x: 0.5057011842727661
#     y: 0.3898962140083313
#   }
#   relative_keypoints {
#     x: 0.6427552700042725
#     y: 0.4057691693305969
#   }
#   relative_keypoints {
#     x: 0.5646551251411438
#     y: 0.44644880294799805
#   }
#   relative_keypoints {
#     x: 0.5567542314529419
#     y: 0.5641459822654724
#   }
#   relative_keypoints {
#     x: 0.4263129234313965
#     y: 0.48602890968322754
#   }
#   relative_keypoints {
#     x: 0.7158182263374329
#     y: 0.5276296138763428
#   }
# }
#
# 0 label_id: 0
# score: 0.9310658574104309
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42525872588157654
#     ymin: 0.3305853009223938
#     width: 0.29877927899360657
#     height: 0.3983581066131592
#   }
#   relative_keypoints {
#     x: 0.5078334212303162
#     y: 0.38918203115463257
#   }
#   relative_keypoints {
#     x: 0.6446729898452759
#     y: 0.4060894250869751
#   }
#   relative_keypoints {
#     x: 0.5674342513084412
#     y: 0.4468890428543091
#   }
#   relative_keypoints {
#     x: 0.5593342781066895
#     y: 0.5645700097084045
#   }
#   relative_keypoints {
#     x: 0.4266539514064789
#     y: 0.4852181077003479
#   }
#   relative_keypoints {
#     x: 0.7169495820999146
#     y: 0.5274999141693115
#   }
# }
#
# 0 label_id: 0
# score: 0.9347655177116394
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4253506362438202
#     ymin: 0.3287951946258545
#     width: 0.3002454340457916
#     height: 0.400312602519989
#   }
#   relative_keypoints {
#     x: 0.5079374313354492
#     y: 0.3889092803001404
#   }
#   relative_keypoints {
#     x: 0.6448826193809509
#     y: 0.4059630036354065
#   }
#   relative_keypoints {
#     x: 0.5666966438293457
#     y: 0.4489366412162781
#   }
#   relative_keypoints {
#     x: 0.5587639808654785
#     y: 0.5659965872764587
#   }
#   relative_keypoints {
#     x: 0.42796120047569275
#     y: 0.4829699397087097
#   }
#   relative_keypoints {
#     x: 0.7182213068008423
#     y: 0.5259718894958496
#   }
# }
#
# 0 label_id: 0
# score: 0.9354668259620667
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42532476782798767
#     ymin: 0.32863521575927734
#     width: 0.30112341046333313
#     height: 0.4014832377433777
#   }
#   relative_keypoints {
#     x: 0.5083816051483154
#     y: 0.38742631673812866
#   }
#   relative_keypoints {
#     x: 0.6468981504440308
#     y: 0.405647337436676
#   }
#   relative_keypoints {
#     x: 0.5681846737861633
#     y: 0.4470840096473694
#   }
#   relative_keypoints {
#     x: 0.559751033782959
#     y: 0.5653347373008728
#   }
#   relative_keypoints {
#     x: 0.42665931582450867
#     y: 0.48287105560302734
#   }
#   relative_keypoints {
#     x: 0.7199300527572632
#     y: 0.5277308821678162
#   }
# }
#
# 0 label_id: 0
# score: 0.9403589963912964
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42524251341819763
#     ymin: 0.32617324590682983
#     width: 0.3036167323589325
#     height: 0.4048078656196594
#   }
#   relative_keypoints {
#     x: 0.5067824721336365
#     y: 0.38767725229263306
#   }
#   relative_keypoints {
#     x: 0.6460806727409363
#     y: 0.4038868546485901
#   }
#   relative_keypoints {
#     x: 0.5651149749755859
#     y: 0.4460607171058655
#   }
#   relative_keypoints {
#     x: 0.5576756000518799
#     y: 0.5648353695869446
#   }
#   relative_keypoints {
#     x: 0.42881008982658386
#     y: 0.482690691947937
#   }
#   relative_keypoints {
#     x: 0.7218360900878906
#     y: 0.5251995921134949
#   }
# }
# 0 label_id: 0
# score: 0.9397969841957092
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4263341724872589
#     ymin: 0.3275004029273987
#     width: 0.30062195658683777
#     height: 0.4008123278617859
#   }
#   relative_keypoints {
#     x: 0.5074618458747864
#     y: 0.3865574598312378
#   }
#   relative_keypoints {
#     x: 0.6462478041648865
#     y: 0.40405935049057007
#   }
#   relative_keypoints {
#     x: 0.566108226776123
#     y: 0.44577616453170776
#   }
#   relative_keypoints {
#     x: 0.5578423738479614
#     y: 0.5640153288841248
#   }
#   relative_keypoints {
#     x: 0.4279521405696869
#     y: 0.48150259256362915
#   }
#   relative_keypoints {
#     x: 0.7205632328987122
#     y: 0.526627242565155
#   }
# }
#
# 0 label_id: 0
# score: 0.9380447864532471
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4264671206474304
#     ymin: 0.3290292024612427
#     width: 0.2989072799682617
#     height: 0.39852631092071533
#   }
#   relative_keypoints {
#     x: 0.5079390406608582
#     y: 0.3877065181732178
#   }
#   relative_keypoints {
#     x: 0.6458946466445923
#     y: 0.40482234954833984
#   }
#   relative_keypoints {
#     x: 0.5671197772026062
#     y: 0.44658297300338745
#   }
#   relative_keypoints {
#     x: 0.5585959553718567
#     y: 0.5643413662910461
#   }
#   relative_keypoints {
#     x: 0.42749640345573425
#     y: 0.48229551315307617
#   }
#   relative_keypoints {
#     x: 0.7186132669448853
#     y: 0.5265159606933594
#   }
# }
#
# 0 label_id: 0
# score: 0.9399464726448059
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4260496199131012
#     ymin: 0.327320396900177
#     width: 0.3009028136730194
#     height: 0.401186466217041
#   }
#   relative_keypoints {
#     x: 0.5075345039367676
#     y: 0.3877682685852051
#   }
#   relative_keypoints {
#     x: 0.645907461643219
#     y: 0.4043174982070923
#   }
#   relative_keypoints {
#     x: 0.5665919780731201
#     y: 0.44833874702453613
#   }
#   relative_keypoints {
#     x: 0.5585489869117737
#     y: 0.5658063292503357
#   }
#   relative_keypoints {
#     x: 0.4279312789440155
#     y: 0.481406033039093
#   }
#   relative_keypoints {
#     x: 0.7198477387428284
#     y: 0.5246999859809875
#   }
# }
#
# 0 label_id: 0
# score: 0.9386751055717468
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42635229229927063
#     ymin: 0.3278893828392029
#     width: 0.29949048161506653
#     height: 0.399303674697876
#   }
#   relative_keypoints {
#     x: 0.5090475678443909
#     y: 0.38815009593963623
#   }
#   relative_keypoints {
#     x: 0.6468990445137024
#     y: 0.4054155945777893
#   }
#   relative_keypoints {
#     x: 0.5689002871513367
#     y: 0.4486144185066223
#   }
#   relative_keypoints {
#     x: 0.5601502656936646
#     y: 0.565314531326294
#   }
#   relative_keypoints {
#     x: 0.42765748500823975
#     y: 0.48077547550201416
#   }
#   relative_keypoints {
#     x: 0.7185429334640503
#     y: 0.5249038338661194
#   }
# }
#
# 0 label_id: 0
# score: 0.9344511032104492
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4258362352848053
#     ymin: 0.3281288743019104
#     width: 0.30069008469581604
#     height: 0.4009023904800415
#   }
#   relative_keypoints {
#     x: 0.5072542428970337
#     y: 0.38769441843032837
#   }
#   relative_keypoints {
#     x: 0.645549476146698
#     y: 0.4050205945968628
#   }
#   relative_keypoints {
#     x: 0.5657710433006287
#     y: 0.447654664516449
#   }
#   relative_keypoints {
#     x: 0.5573946237564087
#     y: 0.5656678676605225
#   }
#   relative_keypoints {
#     x: 0.42774179577827454
#     y: 0.4817427396774292
#   }
#   relative_keypoints {
#     x: 0.7195136547088623
#     y: 0.5267865061759949
#   }
# }
#
# 0 label_id: 0
# score: 0.9360828399658203
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42626523971557617
#     ymin: 0.3281176686286926
#     width: 0.30056166648864746
#     height: 0.40073442459106445
#   }
#   relative_keypoints {
#     x: 0.5073559284210205
#     y: 0.38822025060653687
#   }
#   relative_keypoints {
#     x: 0.6458726525306702
#     y: 0.40446901321411133
#   }
#   relative_keypoints {
#     x: 0.5657998919487
#     y: 0.44489842653274536
#   }
#   relative_keypoints {
#     x: 0.5580154061317444
#     y: 0.5635300278663635
#   }
#   relative_keypoints {
#     x: 0.4290085434913635
#     y: 0.4834306240081787
#   }
#   relative_keypoints {
#     x: 0.7203245162963867
#     y: 0.5258415341377258
#   }
# }
#
# 0 label_id: 0
# score: 0.9311306476593018
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4253990054130554
#     ymin: 0.3275153636932373
#     width: 0.3036647439002991
#     height: 0.40487122535705566
#   }
#   relative_keypoints {
#     x: 0.5061473250389099
#     y: 0.38868141174316406
#   }
#   relative_keypoints {
#     x: 0.6457560658454895
#     y: 0.40387797355651855
#   }
#   relative_keypoints {
#     x: 0.5642297863960266
#     y: 0.4445332884788513
#   }
#   relative_keypoints {
#     x: 0.5572588443756104
#     y: 0.564504086971283
#   }
#   relative_keypoints {
#     x: 0.4291982650756836
#     y: 0.48583167791366577
#   }
#   relative_keypoints {
#     x: 0.7226560115814209
#     y: 0.5265278220176697
#   }
# }
#
# 0 label_id: 0
# score: 0.9292888045310974
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42477691173553467
#     ymin: 0.32950371503829956
#     width: 0.30140531063079834
#     height: 0.4018595814704895
#   }
#   relative_keypoints {
#     x: 0.505132257938385
#     y: 0.3911740183830261
#   }
#   relative_keypoints {
#     x: 0.6431644558906555
#     y: 0.40627115964889526
#   }
#   relative_keypoints {
#     x: 0.5626779794692993
#     y: 0.4474685788154602
#   }
#   relative_keypoints {
#     x: 0.5558633804321289
#     y: 0.5657157897949219
#   }
#   relative_keypoints {
#     x: 0.4288613200187683
#     y: 0.4863317608833313
#   }
#   relative_keypoints {
#     x: 0.7193059325218201
#     y: 0.5265147089958191
#   }
# }
#
# 0 label_id: 0
# score: 0.9302000999450684
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.423240065574646
#     ymin: 0.3287349343299866
#     width: 0.30319744348526
#     height: 0.40424883365631104
#   }
#   relative_keypoints {
#     x: 0.5045482516288757
#     y: 0.39223963022232056
#   }
#   relative_keypoints {
#     x: 0.642638087272644
#     y: 0.40511322021484375
#   }
#   relative_keypoints {
#     x: 0.5634347200393677
#     y: 0.4485800266265869
#   }
#   relative_keypoints {
#     x: 0.5571668744087219
#     y: 0.5670432448387146
#   }
#   relative_keypoints {
#     x: 0.42782777547836304
#     y: 0.48826128244400024
#   }
#   relative_keypoints {
#     x: 0.7184478640556335
#     y: 0.5239688754081726
#   }
# }
